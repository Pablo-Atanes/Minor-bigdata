# %% [markdown]
# # Stap 1
#
# ## Ons Portfolio
#
# ### de samenstelling
# Dit portfolio is samengesteld zodat wij data hebben van veel verschillende markten en typen grondstoffen. Op deze manier kunnen wij kijken of er verbanden liggen tussen deze verschillende markten. Daarnaast kunnen wij onderzoeken welke markten het sterkst reageren op veranderingen in bijvoorbeeld het rentebeleid van de ECB of de inflatie.
#
# ### aandelen, crypto en obligaties
# - LVMH (MC.PA): https://finance.yahoo.com/quote/MC.PA
# - Berkshire Hathaway (BRK-B): https://finance.yahoo.com/quote/BRK-B
# - Microsoft (MSFT): https://finance.yahoo.com/quote/MSFT
# - JPMorgan Chase (JPM): https://finance.yahoo.com/quote/JPM
#
# - US 10-Year Treasury Yield (^TNX): https://finance.yahoo.com/quote/^TNX
# - US 2-Year Treasury Yield (^IRX): https://finance.yahoo.com/quote/^IRX
# - US 30-Year Treasury Yield (^TYX): https://finance.yahoo.com/quote/^TYX
#
# - Bitcoin (BTC-USD): https://finance.yahoo.com/quote/BTC-USD
# - Ethereum (ETH-USD): https://finance.yahoo.com/quote/ETH-USD
# - Solana (SOL-USD): https://finance.yahoo.com/quote/SOL-USD
#
# ### macro-economische indicatoren
# FRED_INDICATOREN
# - "ECBDFR":             "ECB Beleidsrente (%)",
# - "CP0000EZ19M086NEST": "Eurozone Inflatie HICP (%)",
#
# CBS_INDICATOREN
# - "70936ned":           "NL CPI (CBS)",
# - "85224NED":           "NL Werkloosheid (CBS)",
# - "83131NED":           "NL Inflatie (CBS)"
#
#
# ### grondstoffen
# - Goud (GC=F): https://finance.yahoo.com/quote/GC=F
# - Zilver (SI=F): https://finance.yahoo.com/quote/SI=F
# - Ruwe Olie WTI (CL=F): https://finance.yahoo.com/quote/CL=F
# - Brent Olie (BZ=F): https://finance.yahoo.com/quote/BZ=F
# - Aardgas (NG=F): https://finance.yahoo.com/quote/NG=F
# - Koper (HG=F): https://finance.yahoo.com/quote/HG=F
# - Maïs (ZC=F): https://finance.yahoo.com/quote/ZC=F
# - Tarwe (ZW=F): https://finance.yahoo.com/quote/ZW=F
# - Koffie (KC=F): https://finance.yahoo.com/quote/KC=F
# - Soja (ZS=F): https://finance.yahoo.com/quote/ZS=F
#
#
# ## Onderzoeksvragen
#
# 1. Hoe reageert de koers van Microsoft op pieken in de Eurozone en NL inflatiecijfers vergeleken met traditionele "value" aandelen zoals Berkshire Hathaway?
# 2. Hoeveel maanden vertraging zit er tussen een significante stijging in WTI/Brent olie en een stijging in de CBS Inflatiecijfers in Nederland?
# 3. Hoe direct is de doorvertaling van de prijzen van Maïs en Tarwe (ZC=F/ZW=F) naar de CPI (Consumentenprijsindex) van het CBS?
# 4. Wat is de historische correlatie tussen de Aardgas-futures (NG=F) en de NL Werkloosheidscijfers (is er sprake van een vertraagd effect door industriële krimp)?
# 5. In hoeverre correleert een stijging van de ECB-rente met de waardering van Europese luxegoederen (LVMH), gezien de impact op de kapitaalkosten en consumentenbestedingen?
#
# ### Oorzaak, Gevolg en Hypotheses
#
# 1. Microsoft (Growth) vs. Berkshire (Value) en Inflatie
# - Oorzaak (x): Inflatiecijfers (Eurozone HICP / NL CPI).
# - Gevolgen (y): Koersrendement van Microsoft (MSFT) en Berkshire Hathaway (BRK-B).
#
# - H0​: Er is geen significant verschil in de reactie van MSFT en BRK-B op stijgende inflatiecijfers.
# - H1​: Bij stijgende inflatie reageert MSFT (growth) negatiever dan BRK-B (value), vanwege de hogere disconteringsvoet van toekomstige kasstromen.
#
# 2. Olieprijzen en NL Inflatie (Time Lag)
# - Oorzaak (x): Prijsstijgingen van WTI en Brent Olie (CL=F / BZ=F).
# - Gevolg (y): NL Inflatiecijfers (CBS).
#
# - H0​: Er zit geen meetbare vertraging (time lag) tussen een stijging in olieprijzen en de stijging in de NL CPI.
# - H1​: Er is een significante vertraging van 1 tot 3 maanden voordat een stijging in olieprijzen volledig is doorberekend in de NL CPI.
#
# 3. Landbouwgrondstoffen (Maïs/Tarwe) en de CPI
# - Oorzaak (x): Prijzen van Maïs (ZC=F) en Tarwe (ZW=F) futures.
# - Gevolg (y): Consumentenprijsindex (CPI) van het CBS.
#
# - H0​: Er is geen direct verband tussen de prijzen op de internationale grondstofbeurzen voor Maïs/Tarwe en de lokale CPI in Nederland.
# - H1​: Er is een sterke positieve correlatie waarbij stijgende prijzen voor landbouwgrondstoffen leiden tot een stijging in de voedselcomponent van de CPI.
#
# 4. Aardgas-futures en Werkloosheid
# - Oorzaak (x): Aardgas-futures prijs (NG=F).
# - Gevolg (y): NL Werkloosheidscijfer (CBS).
#
# - H0​: Stijgende energieprijzen (aardgas) hebben geen invloed op de werkloosheidscijfers in Nederland.
# - H1​: Een aanhoudende stijging van de aardgasprijs leidt met een vertraging tot een hogere werkloosheid door industriële krimp (energie-intensieve sectoren).
#
# 5. ECB-rente en LVMH (Luxe goederen)
# - Oorzaak (x): ECB Beleidsrente (ECBDFR).
# - Gevolg (y): Koers/Waardering van LVMH (MC.PA).
#
# - H0​: Veranderingen in de ECB-beleidsrente hebben geen invloed op de koers van LVMH.
# - H1​: Een stijging van de ECB-rente correleert negatief met de koers van LVMH, doordat hogere rentes zowel de consumptie onder druk zetten als de waarderingsmultiples verlagen.

# %% [markdown]
# # Stap 2,3 & 4
#
# ## Data Pipeline: Extractie & Opschoning
#
# Om betrouwbare en robuuste resultaten uit onze data-analyse te krijgen, hebben we besloten een volledig geautomatiseerde datapipeline op te zetten. Bij het werken met financiële markten en macro-economische indicatoren realiseerden we ons al snel dat ruwe data zelden direct bruikbaar is. Beurzen zijn in het weekend gesloten, API's leveren soms inconsistente waarden of duplicaten, en verschillende datasets sluiten qua tijdlijnen niet naadloos op elkaar aan.
#
# Daarom hebben we een gestructureerde aanpak gekozen: in onze (Colab/Jupyter) notebook halen we eerst de ruwe data op via onze eigen scripts, om deze vervolgens direct aan een uitgebreid, geautomatiseerd opschoningsproces te onderwerpen. Hieronder lichten we toe hoe we dit hebben ingericht en, nog belangrijker, *waarom* we deze keuzes hebben gemaakt om de kwaliteit van ons onderzoek te waarborgen.
#
# ## 1. De Workflow in de Notebook
#
# Om te voorkomen dat we met verouderde of handmatig bewerkte bestanden werken, voeren we in ons notebook standaard deze twee stappen uit:
#
# 1. **Extractie:** We roepen in de notebook eerst `recieve_ticker_service.py` en `macro_economische_indicatoren.py` aan. Deze scripts communiceren met de API's en verzamelen de actuele ruwe data. Het resultaat wordt opgeslagen in helder gestructureerde JSON-bestanden voor de drie benodigde categorieën: financiële producten, grondstoffen en macro-economische indicatoren. Dit geeft ons een solide, reproduceerbare basis.
# 2. **Opschoning en Transformatie:** Zodra de ruwe data is opgehaald, roepen we direct de functies uit `data_cleaning_service.py` aan over deze bestanden. Dit garandeert dat alle verdere analyses, visualisaties en modellen uitsluitend worden gevoed met een hoogwaardige, gestandaardiseerde dataset.
#
# ## 2. Noodzaak van Intensieve Data-Bewerking
#
# Tijdens de dataverkenning liepen we tegen fundamentele problemen aan die de integriteit van ons onderzoek konden bedreigen. We hebben deze als volgt structureel opgelost in onze cleaning service:
#
# ### Tijdreeksen Synchroniseren en Gaten Vullen (Weekenden)
# Een grote uitdaging met financiële data is dat beurzen in het weekend en tijdens feestdagen dicht zijn. Als we deze dagen simpelweg negeren, lopen de tijdreeksen van verschillende databronnen asynchroon (denk aan crypto, wat wél 24/7 doorgaat). Om alles strak te trekken, dwingen we een kalender-reindex af naar een continue, dagelijkse frequentie (`freq='D'`).
# De lege plekken die zo ontstaan, vullen we veilig op met een **Forward Fill (`ffill`)**. We hebben hier bewust voor gekozen omdat het doortrekken van de laatst bekende slotkoers de realiteit het beste weerspiegelt, zonder ongewenste voorspellingen ('look-ahead bias') te introduceren.
#
# ### Strikte Datatypes en Duplicaten Verwijderen
# API's zijn onvoorspelbaar. Soms leveren ze op dezelfde dag dubbele waarden of bevatten numerieke velden plotseling tekst. Om falende code verderop te voorkomen:
# - Forceren we extreem strikte datatypes. De datums worden gestandaardiseerde Datetime-objecten en prijzen dwingen we numeriek te zijn (`pd.to_numeric(..., errors='coerce')`). Iets wat niet past, wordt een `NaN` en daarna vakkundig weggewerkt door onze *forward fill*.
# - Duplicaten op dezelfde datum filteren we er direct uit (`df[~df.index.duplicated(keep='last')]`). We behouden altijd de laatste waarde, omdat eventuele correcties op een handelsdag doorgaans de meest accurate zijn.
#
# ### Risico's van Extreme Uitschieters (Outliers) Beperken
# Een 'flash-crash' of een simpele typfout in een API kan een extreme piek of dal opleveren. Voor onze statistische modellen zou zo'n uitschieter de berekeningen enorm vertekenen. Om ons hiertegen te beschermen, gebruiken we de **Z-score methode**.
# Wanneer we een waarde tegenkomen die meer dan 3 standaarddeviaties van het gemiddelde ligt, verwijderen we de hele rij niet (want dat verpest onze zorgvuldig gesynchroniseerde kalender weer). In plaats daarvan gebruiken we een techniek genaamd *Winsorizing* (`.clip()`). Hiermee toppen we de extreme waarde letterlijk af op de grens van 3 standaarddeviaties. De structuur blijft intact, maar de verstorende impact is geneutraliseerd.
#
# ### De Data Analyse-Klaar Maken
# Tot slot ontdekten we dat het vergelijken van absolute waarden onbegonnen werk is (hoe vergelijk je een index van 4000 punten met een aandeel van 15 euro?). Daarom berekent onze cleaning service direct de essentiële afgeleide variabelen, zoals dagelijkse procentuele rendementen (`Returns_pct`) en absolute verschillen (`Diff_abs`). Hierdoor maken we de data stationair en zijn onze bestanden in één keer startklaar voor het beantwoorden van de onderzoeksvragen.

# %%
# 1. Installeer de benodigde libraries (alleen nodig als ze nog niet in Colab staan)
# !pip install -r requirements.txt
# Out:
# ...
#   Using cached jinja2-3.1.6-py3-none-any.whl.metadata (2.9 kB)
# ...
#   Using cached vaderSentiment-3.3.2-py2.py3-none-any.whl.metadata (572 bytes)
# ...
#   Using cached multitasking-0.0.13-py3-none-any.whl.metadata (16 kB)
# ...
#   Using cached platformdirs-4.10.0-py3-none-any.whl.metadata (5.5 kB)
# ...
#   Using cached pytz-2026.2-py2.py3-none-any.whl.metadata (22 kB)
# ...
#   Using cached curl_cffi-0.15.0-cp310-abi3-win_amd64.whl.metadata (18 kB)
# ...
#   Using cached websockets-16.0-cp314-cp314-win_amd64.whl.metadata (7.0 kB)
# ...
#   Using cached markupsafe-3.0.3-cp314-cp314-win_amd64.whl.metadata (2.8 kB)
# ...
#   Using cached typing_extensions-4.15.0-py3-none-any.whl.metadata (3.3 kB)
# ...
#   Using cached cffi-2.0.0-cp314-cp314-win_amd64.whl.metadata (2.6 kB)
# ...
#   Using cached rich-15.0.0-py3-none-any.whl.metadata (18 kB)
# ...
#   Using cached pycparser-3.0-py3-none-any.whl.metadata (8.2 kB)
# ...
#   Using cached markdown_it_py-4.2.0-py3-none-any.whl.metadata (7.4 kB)
# ...

# %%
# 2. Haal de ruwe ticker data op (Aandelen, Obligaties, Crypto, Grondstoffen)
# Dit script maakt de map 'ticker_data' aan en vult deze met JSON bestanden.
print("--- STAP 1: Ruwe Ticker data ophalen ---")
from blok2.data_procesing import recieve_ticker_service
recieve_ticker_service.main()
# Out:
# --- STAP 1: Ruwe Ticker data ophalen ---
# Starting data collection and native cleaning for 20 hardcoded tickers.
# Fetching data for MC.PA...
# --> Successfully saved and cleaned MC.PA data to c:\Users\PA4GA\Documents\Minor-bigdata\blok2\data_procesing\ticker_data\MC.PA.json
# Fetching data for BRK-B...
# --> Successfully saved and cleaned BRK-B data to c:\Users\PA4GA\Documents\Minor-bigdata\blok2\data_procesing\ticker_data\BRK-B.json
# Fetching data for MSFT...
# --> Successfully saved and cleaned MSFT data to c:\Users\PA4GA\Documents\Minor-bigdata\blok2\data_procesing\ticker_data\MSFT.json
# Fetching data for JPM...
# --> Successfully saved and cleaned JPM data to c:\Users\PA4GA\Documents\Minor-bigdata\blok2\data_procesing\ticker_data\JPM.json
# Fetching data for ^TNX...
# --> Successfully saved and cleaned ^TNX data to c:\Users\PA4GA\Documents\Minor-bigdata\blok2\data_procesing\ticker_data\TNX.json
# Fetching data for ^IRX...
# ...

# %%
# 3. Haal de ruwe macro-economische data op (CBS & FRED)
# Dit script vult de map 'ticker_data/macro_data' met de benodigde indicatoren.
print("\n--- STAP 2: Macro-economische data ophalen ---")
from blok2.data_procesing import macro_economische_indicatoren
# We roepen de functies aan die in het script staan
macro_economische_indicatoren.haal_fred_data_op(macro_economische_indicatoren.OUTPUT_DIR)
macro_economische_indicatoren.haal_cbs_data_op(macro_economische_indicatoren.OUTPUT_DIR)
# Out:
# --- STAP 2: Macro-economische data ophalen ---
# \n📡 FRED — 2 indicatoren ophalen en cleanen...
# \n📥 ECB Beleidsrente (%) (ECBDFR)
#    ✅ Succesvol weggeschreven (gecleaned): c:\Users\PA4GA\Documents\Minor-bigdata\blok2\data_procesing\ticker_data\macro_data\ECBDFR.json
# \n📥 Eurozone Inflatie HICP (%) (CP0000EZ19M086NEST)
#    ✅ Succesvol weggeschreven (gecleaned): c:\Users\PA4GA\Documents\Minor-bigdata\blok2\data_procesing\ticker_data\macro_data\CP0000EZ19M086NEST.json
# \n📡 CBS — 3 indicatoren ophalen en cleanen...
# \n📥 NL CPI (CBS) (70936ned) | Value column: JaarmutatieCPI_1
#    ✅ Succesvol weggeschreven (gecleaned): c:\Users\PA4GA\Documents\Minor-bigdata\blok2\data_procesing\ticker_data\macro_data\CBS_70936ned.json
# \n📥 NL Werkloosheid (CBS) (85224NED) | Value column: Werkloosheidspercentage_25
#    ✅ Succesvol weggeschreven (gecleaned): c:\Users\PA4GA\Documents\Minor-bigdata\blok2\data_procesing\ticker_data\macro_data\CBS_85224NED.json
# ...

# %% [markdown]
# # Stap 5
#
# ## Beschrijf en verklaar de data met behulp van statistiek
#
# ### 1. Centrale Tendens: Waar ligt het zwaartepunt?
#
# Om een beeld te krijgen van de "normale" waarde van een ticker of indicator, gebruiken we drie verschillende maatstaven. Elke maatstaf belicht een andere kant van de 'gemiddelde' staat van onze portfolio's:
#
# - **Gemiddelde (Mean):** Dit is de rekenkundige optelsom van alle waarden gedeeld door het aantal observaties. In onze analyse gebruiken we dit om de algemene 'koersrichting' of het basisniveau van een macro-economische variabele te bepalen over de gehele tijdsperiode. Het gemiddelde is echter gevoelig voor extreme uitschieters; één dag met een enorme beurscrash trekt het hele gemiddelde naar beneden, ook als de rest van de periode stabiel was.
# - **Mediaan (Median):** De mediaan is de middelste waarde wanneer alle data op volgorde van klein naar groot wordt gezet. Het grote voordeel van de mediaan in financiële markten is de robuustheid. Omdat de mediaan niet kijkt naar de *waarde* van de uitersten, maar alleen naar de *positie*, geeft het ons een veel eerlijker beeld van de "typische" handelsdag. Als het gemiddelde veel lager ligt dan de mediaan, weten we direct dat er sprake is van een 'long tail' aan negatieve uitschieters.
# - **Modus (Mode):** De modus is de waarde die het meest frequent voorkomt in de dataset. Bij aandelenkoersen die tot op 6 decimalen nauwkeurig zijn, is de modus vaak minder relevant. Echter, voor ons onderzoek naar de **ECB-rente** is de modus cruciaal. Centrale banken laten de rente vaak maandenlang op exact hetzelfde niveau staan. De modus vertelt ons dus wat het 'normale beleid' was tijdens de onderzochte periode, ongeacht tijdelijke verhogingen of verlagingen.

# %%
# import all functions
from blok2.data_procesing.statistical_analysis_service import show_central_tendency, show_dispersion, show_shape_statistics, \
    show_distribution_plots, show_correlation_heatmap, show_scatter_plot


# Toon de centrale tendens voor de drie portfolio's
show_central_tendency('financial')
show_central_tendency('commodities')
show_central_tendency('macro')
# Out:
# ### Central Tendency: financial
# <style type="text/css">
# </style>
# <table id="T_5b77b">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_5b77b_level0_col0" class="col_heading level0 col0" >Mean</th>
#       <th id="T_5b77b_level0_col1" class="col_heading level0 col1" >Median</th>
#       <th id="T_5b77b_level0_col2" class="col_heading level0 col2" >Mode</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_5b77b_level0_row0" class="row_heading level0 row0" >MC.PA</th>
#       <td id="T_5b77b_row0_col0" class="data row0 col0" >539.88</td>
#       <td id="T_5b77b_row0_col1" class="data row0 col1" >571.82</td>
#       <td id="T_5b77b_row0_col2" class="data row0 col2" >570.09</td>
#     </tr>
#     <tr>
#       <th id="T_5b77b_level0_row1" class="row_heading level0 row1" >BRK-B</th>
#       <td id="T_5b77b_row1_col0" class="data row1 col0" >328.65</td>
#       <td id="T_5b77b_row1_col1" class="data row1 col1" >308.90</td>
# ...

# %% [markdown]
# ### 2. Spreiding en Risico: Hoe onrustig is de markt?
#
# De centrale tendens vertelt ons waar de data zich bevindt, maar de spreiding vertelt ons hoe betrouwbaar die positie is. In de financiële wereld staat spreiding synoniem voor risico:
#
# - **Standaardafwijking (Standard Deviation):** Dit is voor ons de primaire maatstaf voor **volatiliteit**. Het geeft aan hoeveel de koers van dag tot dag afwijkt van het gemiddelde. Een hoge standaardafwijking bij bijvoorbeeld Bitcoin (BTC-USD) vergeleken met de US 10-Year Treasury Yield (^TNX) laat direct het enorme verschil in risicoprofiel zien. Voor onze onderzoeksvragen is dit essentieel: we willen weten of een aandeel 'heftiger' of juist 'rustiger' op inflatiecijfers reageert dan de algemene markt.
# - **Minimum & Maximum:** De uitersten definiëren het historische bereik binnen onze dataset. Dit helpt ons bij het identificeren van de 'worst-case' en 'best-case' scenario's. Door naar deze uitersten te kijken, kunnen we vaststellen hoe diep de markt daadwerkelijk viel tijdens een crisisperiode of hoe hoog de inflatie piekte. Dit geeft context aan de gemiddelde waarden en laat zien hoe breed het speelveld van onze variabelen is.

# %%
# Toon de spreiding en volatiliteit
show_dispersion('financial')
show_dispersion('commodities')
show_dispersion('macro')
# Out:
# ### Dispersion and Risk: financial
# <style type="text/css">
# </style>
# <table id="T_e7e17">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_e7e17_level0_col0" class="col_heading level0 col0" >Standard Deviation</th>
#       <th id="T_e7e17_level0_col1" class="col_heading level0 col1" >Min</th>
#       <th id="T_e7e17_level0_col2" class="col_heading level0 col2" >Max</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_e7e17_level0_row0" class="row_heading level0 row0" >MC.PA</th>
#       <td id="T_e7e17_row0_col0" class="data row0 col0" >152.64</td>
#       <td id="T_e7e17_row0_col1" class="data row0 col1" >213.74</td>
#       <td id="T_e7e17_row0_col2" class="data row0 col2" >837.37</td>
#     </tr>
#     <tr>
#       <th id="T_e7e17_level0_row1" class="row_heading level0 row1" >BRK-B</th>
#       <td id="T_e7e17_row1_col0" class="data row1 col0" >105.80</td>
# ...

# %% [markdown]
# ### 3. Vorm van de Verdeling: De verborgen risico's
#
# Financiële data volgt zelden een perfecte "normaalverdeling" (de bekende klokvorm). De afwijkingen van deze vorm vertellen ons veel over de verborgen risico's:
#
# - **Skewness (Scheefheid):**
#     - Een **negatieve scheefheid** betekent dat er een langere staart aan de linkerkant zit. In de aandelenmarkt is dit een bekend fenomeen: koersen stijgen vaak gestaag ('climbing the wall of worry') maar kunnen plotseling en hard dalen. Dit vertelt ons dat er een grotere kans is op extreme verliezen dan op extreme winsten.
#     - Een **positieve scheefheid** zien we vaak bij grondstoffen. Bij een plotseling tekort aan bijvoorbeeld aardgas of olie kan de prijs in zeer korte tijd exploderen, wat leidt tot een lange staart aan de rechterkant van de verdeling.
# - **Kurtosis (Spitsheid):** Dit meet de dikte van de staarten, ook wel 'Fat Tails' genoemd. Een hoge kurtosis betekent dat extreme gebeurtenissen (zwarte zwanen) vaker voorkomen dan je op basis van een theoretisch model zou verwachten. Voor ons onderzoek is dit een cruciale waarschuwing: een hoge kurtosis in de inflatiedata suggereert dat prijsschokken vaak heftiger en grilliger zijn dan de normale marktfluctuaties doen vermoeden.

# %%
# Toon de skewness en kurtosis
show_shape_statistics('financial')
show_shape_statistics('commodities')
show_shape_statistics('macro')
# Out:
# ### Shape of Distribution: financial
# <style type="text/css">
# </style>
# <table id="T_407ad">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_407ad_level0_col0" class="col_heading level0 col0" >Skewness</th>
#       <th id="T_407ad_level0_col1" class="col_heading level0 col1" >Kurtosis</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_407ad_level0_row0" class="row_heading level0 row0" >MC.PA</th>
#       <td id="T_407ad_row0_col0" class="data row0 col0" >-0.19</td>
#       <td id="T_407ad_row0_col1" class="data row0 col1" >-0.94</td>
#     </tr>
#     <tr>
#       <th id="T_407ad_level0_row1" class="row_heading level0 row1" >BRK-B</th>
#       <td id="T_407ad_row1_col0" class="data row1 col0" >0.37</td>
#       <td id="T_407ad_row1_col1" class="data row1 col1" >-1.17</td>
#     </tr>
#     <tr>
#       <th id="T_407ad_level0_row2" class="row_heading level0 row2" >MSFT</th>
# ...

# %% [markdown]
# ### 4. Visuele Analyse: Histogrammen en Boxplots
#
# Omdat getallen alleen niet altijd het hele verhaal vertellen, gebruiken we visualisaties om patronen en afwijkingen direct zichtbaar te maken:
#
# - **Histogrammen met KDE:** Een histogram deelt de data op in kleine stukjes ('bins') om te laten zien hoe vaak bepaalde waarden voorkomen. De **KDE (Kernel Density Estimate)** lijn trekt daar een vloeiende vorm overheen. Dit stelt ons in staat om direct te zien of een verdeling 'gepiekt' is (veel waarden rond het gemiddelde) of juist 'plat' (veel spreiding). We kunnen hiermee visueel bevestigen of de inflatiecijfers bijvoorbeeld geclusterd zijn rond de doelstelling van 2% of dat er sprake is van een brede, onvoorspelbare spreiding.
# - **Boxplots:** De boxplot is onze beste tool voor het detecteren van **outliers** (uitschieters). De "box" zelf bevat de middelste 50% van de data. De lijnen die eruit steken (de whiskers) tonen het normale bereik. Alles wat daarbuiten valt als losse puntjes, zijn de extreme dagen. Dit laat ons zien of de extreme waarden die we in de cleaning-fase hebben behandeld (via Winsorizing) nog steeds een significante rol spelen of dat de kern van de data stabiel is gebleven.

# %%
# Voorbeeld: Visualiseer de verdeling van Microsoft en de ECB rente
show_distribution_plots('financial', ticker='MSFT')
show_distribution_plots('macro', ticker='ECBDFR')

# %% [markdown]
# # Stap 6 Grafieken
#
# Om onze onderzoeksvragen te beantwoorden, is het niet voldoende om alleen naar individuele tickers te kijken. We moeten de **onderlinge relaties** tussen financiële markten, grondstoffen en macro-economische indicatoren blootleggen. Hiervoor gebruiken we correlatiematrices en spreidingsdiagrammen (scatter plots).
#
# ## 1. Correlatiematrices en Heatmaps
#
# Een correlatiematrix toont in één oogopslag hoe sterk twee variabelen samen bewegen (tussen -1 en 1).
# - **Positieve correlatie (rood):** Als de ene variabele stijgt, stijgt de andere vaak ook (bijvoorbeeld olie en inflatie).
# - **Negatieve correlatie (blauw):** Als de ene stijgt, daalt de andere (bijvoorbeeld rente en sommige aandelenkoersen).
#
# We maken heatmaps per portfolio om de interne dynamiek te begrijpen, en een **gecombineerde heatmap** van alle 3 de portfolio's om de cross-market relaties te ontdekken.

# %% [markdown]
# Binnen het portfolio Financial Products kijken we naar de samenhang tussen aandelen (MSFT, LVMH), cryptocurrencies (BTC, SOL) en obligatierentes (TNX, TYX). We onderzoeken of 'risk-on' assets tegelijkertijd bewegen en hoe tech-aandelen reageren op de 10-jaars rente. Een negatieve correlatie bevestigt de theorie dat hogere kapitaalkosten groei-aandelen onder druk zetten.

# %%
# Toon de gecombineerde correlatie van ALLES (Financieel + Grondstoffen + Macro)
show_correlation_heatmap('financial')
# Out:
# ### Correlation Table: financial
# <style type="text/css">
# #T_69105_row0_col0, #T_69105_row1_col1, #T_69105_row2_col2, #T_69105_row3_col3, #T_69105_row4_col4, #T_69105_row5_col5, #T_69105_row6_col6, #T_69105_row7_col7, #T_69105_row8_col8, #T_69105_row9_col9 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_69105_row0_col1, #T_69105_row0_col2, #T_69105_row0_col3, #T_69105_row0_col7, #T_69105_row3_col0, #T_69105_row5_col8, #T_69105_row5_col9, #T_69105_row8_col4, #T_69105_row8_col5, #T_69105_row8_col6 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_69105_row0_col4 {
#   background-color: #6b8df0;
#   color: #f1f1f1;
# }
# #T_69105_row0_col5 {
#   background-color: #b3cdfb;
#   color: #000000;
# }
# #T_69105_row0_col6 {
#   background-color: #4055c8;
#   color: #f1f1f1;
# }
# #T_69105_row0_col8 {
#   background-color: #dbdcde;
#   color: #000000;
# }
# #T_69105_row0_col9 {
#   background-color: #5875e1;
#   color: #f1f1f1;
# }
# ...

# %% [markdown]
# ### Toelichting
#
# Het meest opvallende is hoe sterk de Amerikaanse markten intern samenhangen. De grote aandelen zoals Microsoft, Berkshire Hathaway en JPMorgan bewegen vrijwel in lockstep, met correlaties tussen de 0.89 en 0.94. Dit is kenmerkend voor een marktperiode waarin macro-factoren, zoals rentebeleid en risicosentiment, de boventoon voeren en individuele bedrijfsresultaten er minder toe doen.
# De rentemarkt vertelt een vergelijkbaar verhaal. TNX, IRX en TYX, respectievelijk de korte, middellange en lange Amerikaanse rente, lopen met correlaties tot 0.99 vrijwel perfect gelijk. Dat is op zich niet verrassend, want ze worden allemaal gestuurd door hetzelfde Fed-beleid.
#
# Crypto gedraagt zich als één blok. Bitcoin, Ethereum en Solana bewegen sterk samen met onderlinge correlaties rond de 0.88, wat aangeeft dat beleggers de hele cryptomarkt als één risicocategorie behandelen. Wat wél opvalt is dat Bitcoin ook sterk correleert met JPMorgan (0.92) en Microsoft (0.91). Dit suggereert dat in deze periode zowel aandelen als crypto door dezelfde liquiditeitsgolf werden meegesleurd.
#
# De echte buitenbeentje is MC.PA, het aandeel van LVMH. Als enige Europese waarde in de matrix heeft het de laagste correlaties met vrijwel alles, en met name de relatie met JPMorgan (0.32) en Bitcoin (0.37) is opvallend zwak. LVMH leeft duidelijk in een andere wereld dan de Amerikaanse financiële markten.
#
# De overall conclusie is dat er in deze periode weinig echte diversificatie zat tussen de klassen. Wie dacht te spreiden door zowel aandelen als crypto aan te houden, had feitelijk twee keer hetzelfde risico in portefeuille.

# %% [markdown]
# In het Commodities portfolio analyseren we de relatie tussen energie (olie/gas), edelmetalen (goud/zilver) en landbouwproducten. We onderzoeken of energieprijzen en voedselprijzen gecorreleerd zijn door transportkosten en of goud fungeert als 'veilige haven' tijdens periodes van hoge inflatie.

# %%
show_correlation_heatmap('commodities')
# Out:
# ### Correlation Table: commodities
# <style type="text/css">
# #T_02303_row0_col0, #T_02303_row1_col1, #T_02303_row2_col2, #T_02303_row3_col3, #T_02303_row4_col4, #T_02303_row5_col5, #T_02303_row6_col6, #T_02303_row7_col7, #T_02303_row8_col8, #T_02303_row9_col9 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_02303_row0_col1, #T_02303_row1_col0 {
#   background-color: #c12b30;
#   color: #f1f1f1;
# }
# #T_02303_row0_col2, #T_02303_row0_col3, #T_02303_row0_col4, #T_02303_row0_col6, #T_02303_row0_col7, #T_02303_row0_col9, #T_02303_row7_col0, #T_02303_row7_col1, #T_02303_row7_col5, #T_02303_row7_col8 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_02303_row0_col5 {
#   background-color: #f6a586;
#   color: #000000;
# }
# #T_02303_row0_col8 {
#   background-color: #ec7f63;
#   color: #f1f1f1;
# }
# #T_02303_row1_col2 {
#   background-color: #445acc;
#   color: #f1f1f1;
# }
# #T_02303_row1_col3 {
#   background-color: #455cce;
#   color: #f1f1f1;
# }
# ...

# %% [markdown]
# ### Toelichting
#
# Dit zijn grondstoffenfutures verdeeld over drie duidelijke clusters: edele metalen (goud, zilver, koper), energie (olie, aardgas) en agrarisch (maïs, tarwe, soja).
#
# De edele metalen bewegen vrijwel identiek, met goud en zilver op 0.96. Koper volgt op afstand met correlaties rond de 0.78-0.80, gedreven door zijn extra industriële component. In de energiemarkt lopen WTI en Brent met 0.99 vrijwel perfect gelijk — logisch, want het is in essentie hetzelfde product. Aardgas doet gedeeltelijk mee maar heeft door seizoenspatronen en regionale prijsverschillen zijn eigen dynamiek. Maïs, tarwe en soja bewegen sterk samen (0.84-0.92), allemaal gevoelig voor dezelfde oogst- en weerfactoren.
# Het meest opvallende zijn de licht negatieve correlaties tussen edele metalen en granen. Goud en zilver zijn vluchtwaarden bij onzekerheid, terwijl granen reageren op landbouwcycli — fundamenteel verschillende drijfveren dus. Koffie is de buitenbeentje: het correleert verrassend sterk met goud en koper, maar nauwelijks met de andere agrarische grondstoffen.
# De grote conclusie verschilt sterk van de financiële matrix van eerder: grondstoffen bieden wél echte diversificatie, omdat de drie clusters grotendeels onafhankelijk van elkaar bewegen.

# %% [markdown]
# De Macro heatmap focust op het centrale bankbeleid. We kijken naar de relatie tussen de ECB-rente en de inflatiecijfers (Eurozone HICP en NL CPI). We verwachten een verband tussen stijgende inflatie en de daaropvolgende renteverhogingen om de economie af te koelen.

# %%
show_correlation_heatmap('macro')
# Out:
# ### Correlation Table: macro
# <style type="text/css">
# #T_eccc6_row0_col0, #T_eccc6_row1_col1, #T_eccc6_row1_col4, #T_eccc6_row2_col2, #T_eccc6_row3_col3, #T_eccc6_row4_col1, #T_eccc6_row4_col4 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_eccc6_row0_col1, #T_eccc6_row1_col0 {
#   background-color: #d0473d;
#   color: #f1f1f1;
# }
# #T_eccc6_row0_col2 {
#   background-color: #9fbfff;
#   color: #000000;
# }
# #T_eccc6_row0_col3 {
#   background-color: #3d50c3;
#   color: #f1f1f1;
# }
# #T_eccc6_row0_col4 {
#   background-color: #d55042;
#   color: #f1f1f1;
# }
# #T_eccc6_row1_col2 {
#   background-color: #f7b194;
#   color: #000000;
# }
# #T_eccc6_row1_col3 {
#   background-color: #3e51c5;
#   color: #f1f1f1;
# }
# #T_eccc6_row2_col0 {
#   background-color: #b6cefa;
#   color: #000000;
# }
# #T_eccc6_row2_col1 {
#   background-color: #f7a688;
#   color: #000000;
# }
# #T_eccc6_row2_col3 {
#   background-color: #5a78e4;
#   color: #f1f1f1;
# }
# #T_eccc6_row2_col4 {
# ...

# %% [markdown]
# ### Toelichting
#
# Dit zijn macroeconomische indicatoren. Even de tickers duiden:
#
# - ECBDFR = ECB depositorente
# - CP0000EZ19M086NEST = Eurozone inflatie (HICP)
# - CBS_70936ned = Nederlandse woningprijzen
# - CBS_85224NED = Nederlandse bevolkingsgroei (of huishoudens)
# - CBS_83131NED = Nederlandse consumentenbestedingen (of inkomen)
#
# De matrix laat een herkenbaar macro-economisch patroon zien. De ECB-rente en inflatie bewegen sterk samen (0.86), wat de kern van het monetaire beleid van de afgelopen jaren blootlegt: de ECB verhoogde de rente direct als reactie op stijgende inflatie, waardoor beide series vrijwel gelijktijdig bewogen.
# Het meest opvallende signaal komt van CBS_85224NED, dat sterk negatief correleert met vrijwel alles: -0.76 met zowel de ECB-rente als inflatie, en -0.78 met CBS_83131NED. Dit suggereert dat deze indicator juist daalde terwijl rente en inflatie stegen, wat past bij bijvoorbeeld koopkracht of reëel besteedbaar inkomen, dat onder inflatiedruk afneemt.
# Nederlandse woningprijzen (CBS_70936ned) vertonen een zwak negatief verband met de ECB-rente (-0.11) maar correleren matig positief met inflatie (0.50). Dit weerspiegelt het tweezijdige effect van inflatie op de woningmarkt: hogere rentes remmen de markt, maar inflatie drijft de nominale prijzen juist op.
# De grote lijn is duidelijk: stijgende rente en inflatie gaan hand in hand, terwijl een van de CBS-indicatoren daar consequent tegenin beweegt — een klassiek teken van koopkrachterosie in een hooginflatieperiode.

# %% [markdown]
# In deze gecombineerde matrix brengen we alle drie de werelden samen. Hier ontdekken we de echte 'cross-market' effecten, zoals de invloed van aardgas-prijzen op de Nederlandse werkloosheid of de reactie van Bitcoin op de officiële ECB-rente. Dit geeft het meest complete beeld van de economische verwevenheid.

# %%
show_correlation_heatmap('combined')
# Out:
# ### Correlation Table: combined
# <style type="text/css">
# #T_b2d7c_row0_col0, #T_b2d7c_row1_col1, #T_b2d7c_row2_col2, #T_b2d7c_row3_col3, #T_b2d7c_row4_col4, #T_b2d7c_row5_col5, #T_b2d7c_row6_col6, #T_b2d7c_row7_col7, #T_b2d7c_row8_col8, #T_b2d7c_row9_col9, #T_b2d7c_row10_col10, #T_b2d7c_row11_col11, #T_b2d7c_row12_col12, #T_b2d7c_row12_col13, #T_b2d7c_row13_col12, #T_b2d7c_row13_col13, #T_b2d7c_row14_col14, #T_b2d7c_row15_col15, #T_b2d7c_row16_col16, #T_b2d7c_row17_col17, #T_b2d7c_row18_col18, #T_b2d7c_row19_col19, #T_b2d7c_row20_col20, #T_b2d7c_row21_col21, #T_b2d7c_row21_col24, #T_b2d7c_row22_col22, #T_b2d7c_row23_col23, #T_b2d7c_row24_col21, #T_b2d7c_row24_col24 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_b2d7c_row0_col1, #T_b2d7c_row8_col6, #T_b2d7c_row20_col15 {
#   background-color: #f7b396;
#   color: #000000;
# }
# #T_b2d7c_row0_col2, #T_b2d7c_row1_col0, #T_b2d7c_row4_col15, #T_b2d7c_row6_col0, #T_b2d7c_row12_col14 {
#   background-color: #f6a385;
# ...

# %% [markdown]
# ### Toelichting
#
# Aandelen en crypto bewegen sterk samen. BTC, ETH en SOL hebben hoge correlaties met aandelen zoals MSFT, JPM en BRK-B (0.79 tot 0.92). Dit suggereert dat crypto in deze periode meer als risicovolle groei-asset gedroeg dan als alternatieve valuta of safe haven.
# Grondstoffen zijn meer verdeeld. Goud (GC_F) en zilver (SI_F) correleren sterk met elkaar (0.96) maar matig met aandelen. Olie (CL_F) en Brent (BZ_F) bewegen ook sterk samen (0.99) maar anders dan de rest.
# CBS_85224NED is een uitzondering, deze heeft bijna overal negatieve correlaties, wat hem interessant maakt als diversificatie-instrument in een portefeuille.
# Rentes (TNX, IRX, TYX) correleren onderling sterk (0.90-0.99) wat logisch is, maar ook verrassend hoog met aandelen en crypto, wat kan wijzen op een specifieke marktperiode.

# %% [markdown]
# ## 2. Analyse per Onderzoeksvraag (Scatter Plots & Tabellen)
#
# Voor elke onderzoeksvraag gebruiken we minstens één tabel en één grafiektype (een scatter plot met een regressielijn) om de relatie visueel te toetsen. De functie `show_scatter_plot()` genereert automatisch beide: een samenvattende tabel met de correlatiecoëfficiënt en de bijbehorende grafiek.
#
# ### Onderzoeksvraag 1: Microsoft vs Inflatie
# We kijken of er een negatief verband is tussen de inflatie en de koers van tech-reuzen.

# %%
# Gebruik 'CBS_83131NED' in plaats van '83131NED'
show_scatter_plot('macro', 'CBS_83131NED', 'financial', 'MSFT', title="Relatie NL Inflatie vs MSFT Koers")
# Out:
# ### Data Tabel: CBS_83131NED vs MSFT
# <style type="text/css">
# </style>
# <table id="T_3d186">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_3d186_level0_col0" class="col_heading level0 col0" >count</th>
#       <th id="T_3d186_level0_col1" class="col_heading level0 col1" >mean</th>
#       <th id="T_3d186_level0_col2" class="col_heading level0 col2" >std</th>
#       <th id="T_3d186_level0_col3" class="col_heading level0 col3" >min</th>
#       <th id="T_3d186_level0_col4" class="col_heading level0 col4" >25%</th>
#       <th id="T_3d186_level0_col5" class="col_heading level0 col5" >50%</th>
#       <th id="T_3d186_level0_col6" class="col_heading level0 col6" >75%</th>
#       <th id="T_3d186_level0_col7" class="col_heading level0 col7" >max</th>
#       <th id="T_3d186_level0_col8" class="col_heading level0 col8" >Correlation</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
# ...

# %% [markdown]
# ### Toelichting
#
# De scatterplot toont de relatie tussen de Nederlandse inflatie-index (CBS_83131NED) en de koers van Microsoft (MSFT) over 84 maandelijkse datapunten.
# De correlatie van r = 0.90 is opvallend hoog, dit betekent dat wanneer de inflatie steeg, de Microsoft koers in dezelfde periode ook steeg. Dit is het tegenovergestelde van wat de onderzoeksvraag verwachtte, namelijk een negatief verband.

# %% [markdown]
# ### Onderzoeksvraag 2: Olieprijzen en NL Inflatie
# Hier toetsen we de hypothese dat stijgende energieprijzen de inflatie aanjagen.

# %%
show_scatter_plot('commodities', 'CL_F', 'macro', 'CBS_70936ned', title="WTI Olie vs NL CPI")
# Out:
# ### Data Tabel: CL_F vs CBS_70936ned
# <style type="text/css">
# </style>
# <table id="T_5f08b">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_5f08b_level0_col0" class="col_heading level0 col0" >count</th>
#       <th id="T_5f08b_level0_col1" class="col_heading level0 col1" >mean</th>
#       <th id="T_5f08b_level0_col2" class="col_heading level0 col2" >std</th>
#       <th id="T_5f08b_level0_col3" class="col_heading level0 col3" >min</th>
#       <th id="T_5f08b_level0_col4" class="col_heading level0 col4" >25%</th>
#       <th id="T_5f08b_level0_col5" class="col_heading level0 col5" >50%</th>
#       <th id="T_5f08b_level0_col6" class="col_heading level0 col6" >75%</th>
#       <th id="T_5f08b_level0_col7" class="col_heading level0 col7" >max</th>
#       <th id="T_5f08b_level0_col8" class="col_heading level0 col8" >Correlation</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
# ...

# %% [markdown]
# ### Toelichting
#
# Deze scatterplot onderzoekt de hypothese dat stijgende energieprijzen de inflatie aanjagen, door WTI olie (CL_F) te vergelijken met de Nederlandse CPI (CBS_70936ned) over 51 datapunten.
#
# De correlatie van r = 0.62 is matig tot sterk positief, er is dus een duidelijk verband tussen hogere olieprijzen en hogere inflatie, wat de hypothese ondersteunt. Dit is ook economisch goed te verklaren: energie is een directe inputkost voor transport, productie en verwarming, waardoor olieprijsstijgingen vrijwel direct doorwerken in de consumentenprijzen.
#
# Wat de data tabel zegt:
#
# De olieprijs (CL_F) schommelde sterk tussen $19.78 en $115.26 met een gemiddelde van $67.80, dit weerspiegelt de grote volatiliteit van olie, inclusief de coronadip in 2020 en de piek na de Russische invasie van Oekraïne in 2022. De CPI (CBS_70936ned) beweegt in een smaller bereik van -0.40 tot 12.81, met een gemiddelde van 4.65%, het negatieve minimum wijst op een korte deflatieperiode.
#
# Wat de plot zegt:
#
# De spreiding rondom de trendlijn is groter dan bij onderzoeksvraag 1, wat de lagere correlatie verklaart. Er zijn duidelijke uitschieters zichtbaar, periodes waar inflatie hoog was terwijl de olieprijs dat niet was, of vice versa. Dit suggereert dat olie niet de enige drijver van inflatie is, maar wel een significante.

# %% [markdown]
# ### Onderzoeksvraag 3: Landbouwgrondstoffen (Maïs/Tarwe) en de CPI
# Heeft de prijs van graan op de wereldmarkt direct effect op de consumentenprijzen?

# %%
show_scatter_plot('commodities', 'ZW_F', 'macro', 'CBS_70936ned', title="Tarwe Futures vs NL CPI")
# Out:
# ### Data Tabel: ZW_F vs CBS_70936ned
# <style type="text/css">
# </style>
# <table id="T_809fa">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_809fa_level0_col0" class="col_heading level0 col0" >count</th>
#       <th id="T_809fa_level0_col1" class="col_heading level0 col1" >mean</th>
#       <th id="T_809fa_level0_col2" class="col_heading level0 col2" >std</th>
#       <th id="T_809fa_level0_col3" class="col_heading level0 col3" >min</th>
#       <th id="T_809fa_level0_col4" class="col_heading level0 col4" >25%</th>
#       <th id="T_809fa_level0_col5" class="col_heading level0 col5" >50%</th>
#       <th id="T_809fa_level0_col6" class="col_heading level0 col6" >75%</th>
#       <th id="T_809fa_level0_col7" class="col_heading level0 col7" >max</th>
#       <th id="T_809fa_level0_col8" class="col_heading level0 col8" >Correlation</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
# ...

# %% [markdown]
# ### Toelichting
#
# Deze scatterplot onderzoekt of de prijs van graan op de wereldmarkt een direct effect heeft op de Nederlandse consumentenprijzen, door tarwe futures (ZW_F) te vergelijken met de CPI over 51 datapunten.De correlatie van r = 0.79 is sterk positief, sterker dan de relatie tussen olie en inflatie (0.62) uit onderzoeksvraag 2. Dit is opvallend omdat tarwe een directere inputkost is voor voedselproducten die een groot deel van de CPI-mand uitmaken, zoals brood, pasta en veevoer.
#
# Wat de data tabel zegt:
#
# Tarwe (ZW_F) kent een grote prijsspreiding, van 425 tot 1043 cent per bushel met een gemiddelde van 624. De piek boven de 1000 weerspiegelt hoogstwaarschijnlijk de tarieprijsschok na de Russische invasie van Oekraïne in 2022, aangezien beide landen samen goed zijn voor een groot deel van de wereldwijde tarwe-export. De CPI-data is identiek aan onderzoeksvraag 2 (zelfde dataset, 51 datapunten, gemiddelde 4.65%).
#
# Wat de plot zegt:
#
# De spreiding rondom de trendlijn is groter in het lage tarweprijsbereik (500-600), terwijl de punten bij hogere tarieprijzen dichter bij de lijn liggen. Dit suggereert dat het verband sterker wordt bij extreme prijsstijgingen, een drempeleffect waarbij pas boven een bepaalde prijs de doorwerking naar consumentenprijzen echt merkbaar wordt.

# %% [markdown]
# ### Onderzoeksvraag 4: Aardgas en Werkloosheid
# Heeft de energieprijscrisis invloed op de arbeidsmarkt?

# %%
show_scatter_plot('commodities', 'NG_F', 'macro', 'CBS_85224NED', title="Aardgas vs Werkloosheid")
# Out:
# ### Data Tabel: NG_F vs CBS_85224NED
# <style type="text/css">
# </style>
# <table id="T_8cf54">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_8cf54_level0_col0" class="col_heading level0 col0" >count</th>
#       <th id="T_8cf54_level0_col1" class="col_heading level0 col1" >mean</th>
#       <th id="T_8cf54_level0_col2" class="col_heading level0 col2" >std</th>
#       <th id="T_8cf54_level0_col3" class="col_heading level0 col3" >min</th>
#       <th id="T_8cf54_level0_col4" class="col_heading level0 col4" >25%</th>
#       <th id="T_8cf54_level0_col5" class="col_heading level0 col5" >50%</th>
#       <th id="T_8cf54_level0_col6" class="col_heading level0 col6" >75%</th>
#       <th id="T_8cf54_level0_col7" class="col_heading level0 col7" >max</th>
#       <th id="T_8cf54_level0_col8" class="col_heading level0 col8" >Correlation</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
# ...

# %% [markdown]
# ### Toelichting
#
# Deze scatterplot onderzoekt of de energiepriscrisis invloed heeft gehad op de Nederlandse arbeidsmarkt, door aardgasprijzen (NG_F) te vergelijken met het werkloosheidspercentage (CBS_85224NED) over slechts 25 datapunten.
# De correlatie van r = -0.52 is matig negatief, dit betekent dat hogere aardgasprijzen samengaan met lagere werkloosheid, wat op het eerste gezicht contra-intuïtief lijkt. Je zou verwachten dat een energiecrisis bedrijven onder druk zet en werkloosheid verhoogt, maar de data laat het tegenovergestelde zien.
#
# Hoe dit te verklaren:
#
# De energiecrisis piekde in 2021-2022, een periode waarin de Nederlandse arbeidsmarkt juist extreem krap was na het COVID-herstel. Werkloosheid daalde naar historische dieptepunten terwijl aardgasprijzen stegen. De negatieve correlatie weerspiegelt dus waarschijnlijk dit tijdseffect, twee tegengestelde trends in dezelfde periode, eerder dan een causaal verband.
#
# Wat de data tabel zegt:
#
# Aardgas (NG_F) varieerde sterk van $1.59 tot $8.14 met een gemiddelde van $3.35, wat de extreme prijspieken van de energiecrisis weerspiegelt. De werkloosheid (CBS_85224NED) bewoog in een smal bereik van 3.30% tot 5.30%, wat aangeeft dat de Nederlandse arbeidsmarkt gedurende deze periode relatief stabiel en krap bleef.

# %% [markdown]
# ### Onderzoeksvraag 5: ECB-rente en LVMH
# Hoe reageert de luxe-industrie op de kapitaalkosten?

# %%
show_scatter_plot('macro', 'ECBDFR', 'financial', 'MC.PA', title="ECB Rente vs LVMH Koers")
# Out:
# ### Data Tabel: ECBDFR vs MC.PA
# <style type="text/css">
# </style>
# <table id="T_4abd1">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_4abd1_level0_col0" class="col_heading level0 col0" >count</th>
#       <th id="T_4abd1_level0_col1" class="col_heading level0 col1" >mean</th>
#       <th id="T_4abd1_level0_col2" class="col_heading level0 col2" >std</th>
#       <th id="T_4abd1_level0_col3" class="col_heading level0 col3" >min</th>
#       <th id="T_4abd1_level0_col4" class="col_heading level0 col4" >25%</th>
#       <th id="T_4abd1_level0_col5" class="col_heading level0 col5" >50%</th>
#       <th id="T_4abd1_level0_col6" class="col_heading level0 col6" >75%</th>
#       <th id="T_4abd1_level0_col7" class="col_heading level0 col7" >max</th>
#       <th id="T_4abd1_level0_col8" class="col_heading level0 col8" >Correlation</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
# ...

# %% [markdown]
# ### Toelichting
#
# Deze scatterplot onderzoekt hoe de luxe-industrie reageert op kapitaalkosten, door de ECB-depositorente (ECBDFR) te vergelijken met de koers van LVMH (MC.PA) over 27 datapunten.
# De correlatie van r = 0.62 is positief, wat opvallend en contra-intuïtief is. De klassieke economische theorie stelt dat hogere rentes slecht zijn voor aandelenkoersen omdat toekomstige winsten minder waard worden en lenen duurder wordt. LVMH stijgt hier echter mee met de rente.
#
# Hoe dit te verklaren:
#
# Dit is wederom grotendeels een tijdseffect. De ECB verhoogde de rente stapsgewijs van negatief (-0.50%) naar 4.00% tussen 2022 en 2023, als reactie op hoge inflatie. In diezelfde periode presteerde LVMH uitzonderlijk goed dankzij een sterke post-COVID vraag naar luxegoederen, met name vanuit Azië en de VS. De luxesector is bovendien minder rentegevoelig dan andere sectoren omdat hun klanten kapitaalkrachtig zijn en niet afhankelijk van krediet voor hun aankopen.
#
# Wat de data tabel zegt:
#
# De ECB-rente beweegt van -0.50% tot 4.00% met een gemiddelde van 2.52%, dit weerspiegelt de volledige rentecyclus van nulrente naar verkrapping. LVMH schommelde tussen €225 en €826 met een gemiddelde van €549 en een hoge standaarddeviatie van €161, wat de sterke koersbeweging in deze periode aantoont. Het verschil in datapunten (27 vs 84) suggereert dat de ECB-rente minder frequent beschikbaar is in de dataset.
#
# Wat de plot zegt:
#
# De spreiding is aanzienlijk en de onzekerheidsband breed, wat past bij slechts 27 datapunten. Er zijn duidelijke uitschieters zichtbaar bij lage rentestanden, LVMH-koersen variëren sterk tussen €310 en €638 bij rentes onder nul, wat aangeeft dat andere factoren zoals marktsentiment en Chinese vraag een grote rol speelden.

# %% [markdown]
# # Stap 7 — Meervoudige Regressieanalyses
#
# Voor elk van onze 5 onderzoeksvragen voeren we een **meervoudige regressieanalyse** (Multiple Linear Regression) uit. In tegenstelling tot een enkelvoudige regressie (één X-variabele, zoals in de scatter plots van Stap 6) gebruiken we hier voor elk model **meerdere onafhankelijke variabelen** tegelijk. Dit is essentieel omdat economische verbanden zelden in isolatie bestaan: de koers van MSFT wordt niet alléén door Nederlandse inflatie bepaald, maar ook door Eurozone-inflatie en de algemene marktbeweging (waar BRK-B een goede proxy voor is).
#
# ## Methodologische keuzes
#
# **Library:** We gebruiken `scikit-learn` (`LinearRegression`) voor het schatten van de coëfficiënten en `scipy.stats` om handmatig p-waarden te berekenen — sklearn levert die namelijk niet standaard, terwijl ze wel essentieel zijn voor de statistische toelichting.
#
# **Frequentie — maandelijks:** Onze macro-economische indicatoren (CBS CPI, CBS Werkloosheid, ECB-rente, Eurozone HICP) worden maandelijks gepubliceerd, terwijl de financiële data dagelijks zijn. Om verschillende frequenties consistent te kunnen vergelijken resamplen we **alle** reeksen naar maandelijkse eindwaarden (`.resample('ME').last()`). Forward-fillen van maand-data naar dagelijks zou ons aantal observaties artificieel opblazen en p-waarden onbetrouwbaar maken.
#
# **Lags:** Voor onderzoeksvragen waar we een vertraagd effect verwachten (RQ2: olie → CPI; RQ4: gas → werkloosheid) nemen we de lag-versies (`.shift(n)`) van de driver expliciet mee als aparte X-variabelen. Zo kan de regressie zelf bepalen welke vertraging het sterkst is.
#
# **Train/test-split:** We splitsen de tijdreeks 80/20 (`shuffle=False`, dus chronologisch — eerste 80% train, laatste 20% test). De RMSE op de test-set geeft een eerlijke maat van out-of-sample voorspelkracht, naast de R² op de train-set.
#
# **Returns vs. niveaus:** Voor aandelenkoersen (RQ1, RQ5) gebruiken we maandelijkse procentuele rendementen als Y in plaats van het prijsniveau. Aandelenprijzen zijn niet-stationair en hebben een trend; rendementen wel. Voor macro-indicatoren in niveaus (CPI, werkloosheid) houden we de niveaus aan, omdat dit conceptueel is wat we willen verklaren.
#
# **Multicollineariteit-noot:** In RQ2 zijn `CL_F` (WTI) en zijn lags onderling sterk gecorreleerd, en evenzo in RQ4 voor `NG_F`. Dit kan individuele coëfficiënten lastig interpreteerbaar maken (grote standaardfouten), maar verandert niets aan het globale model-fit. Lag-modellen zijn gangbaar in tijdreeksanalyse en we vermelden expliciet wanneer dit speelt.
#
# ## Hoe lees je de output?
#
# Voor elke RQ tonen we:
# 1. **Coëfficiëntentabel** — voor elke X-variabele de geschatte coëfficiënt, standaardfout, t-waarde en p-waarde. Een p-waarde < 0.05 (groen gemarkeerd) duidt op statistische significantie.
# 2. **Modelfit** — R² en adjusted R² (verklaarde variantie), plus train- en test-RMSE.
# 3. **Scatter werkelijk vs voorspeld** — visuele check van modelfit; punten dicht bij de rode 45°-lijn = goede voorspelling.
# 4. **Conclusie** — automatisch gegenereerde toelichting per predictor, plus een H0/H1-oordeel.

# %%
# Importeer de regressie-service
from blok2.data_procesing.regression_analysis_service import show_regression_analysis

# %% [markdown]
# ## Onderzoeksvraag 1 — Microsoft (Growth) vs. Berkshire (Value) en Inflatie
#
# We toetsen of MSFT (een growth-aandeel) negatiever reageert op stijgende inflatie dan BRK-B (een value-aandeel). Y = MSFT maandelijks rendement (%). X = NL inflatie (CBS_83131NED), Eurozone HICP (CP0000EZ19M086NEST) en BRK-B maandelijks rendement (als controle voor de algemene marktbeweging — zo isoleren we het inflatie-effect dat *uniek* is voor MSFT bovenop wat de hele markt doet).

# %%
show_regression_analysis(
    rq_number=1,
    title="MSFT-rendement verklaard door inflatie en marktbeweging",
    hypothesis_h1="Bij stijgende inflatie reageert MSFT (growth) negatiever dan BRK-B (value), vanwege de hogere disconteringsvoet van toekomstige kasstromen.",
    y_col='MSFT',
    y_as_return=True,
    x_specs=[
        ('CBS_83131NED', 'level', 'NL_inflatie'),
        ('CP0000EZ19M086NEST', 'level', 'EZ_HICP'),
        ('BRK-B', 'return', 'BRK-B_return'),
    ],
    expected_signs={
        'NL_inflatie': '-',
        'EZ_HICP': '-',
        'BRK-B_return': '+',
    },
)
# Out:
# ## Onderzoeksvraag 1: MSFT-rendement verklaard door inflatie en marktbeweging
# **H0:** Er is geen relatie tussen de gekozen predictors en MSFT.
# **H1:** Bij stijgende inflatie reageert MSFT (growth) negatiever dan BRK-B (value), vanwege de hogere disconteringsvoet van toekomstige kasstromen.
# ### Coefficientenschattingen
# <style type="text/css">
# #T_cbf9a_row1_col3, #T_cbf9a_row2_col3, #T_cbf9a_row3_col3 {
#   background-color: #d4edda;
# }
# </style>
# <table id="T_cbf9a">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_cbf9a_level0_col0" class="col_heading level0 col0" >Coefficient</th>
#       <th id="T_cbf9a_level0_col1" class="col_heading level0 col1" >Std Error</th>
#       <th id="T_cbf9a_level0_col2" class="col_heading level0 col2" >t-stat</th>
#       <th id="T_cbf9a_level0_col3" class="col_heading level0 col3" >p-value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
# ...

# %% [markdown]
# ## Onderzoeksvraag 2 — Olieprijzen en NL Inflatie (met vertraging)
#
# We toetsen of een stijging in olieprijzen met 1-3 maanden vertraging doorwerkt in de Nederlandse CPI. Y = NL CPI (CBS_70936ned). X = WTI-olie (`CL_F`) op moment t, plus lags van 1 en 2 maanden, plus Brent (`BZ_F`) als robuustheids-controle (Brent en WTI zijn verschillende benchmarks; als beide significant in dezelfde richting wijzen, versterkt dat het verhaal). De lag-coëfficiënten vertellen ons direct welke vertraging het sterkst is.

# %%
show_regression_analysis(
    rq_number=2,
    title="NL CPI verklaard door olieprijzen (WTI t, t-1, t-2) en Brent",
    hypothesis_h1="Er is een significante vertraging van 1 tot 3 maanden voordat een stijging in olieprijzen volledig is doorberekend in de NL CPI.",
    y_col='CBS_70936ned',
    y_as_return=False,
    x_specs=[
        ('CL_F', 'level', 'WTI_t'),
        ('CL_F', ('lag', 1), 'WTI_t-1'),
        ('CL_F', ('lag', 2), 'WTI_t-2'),
        ('BZ_F', 'level', 'Brent_t'),
    ],
    expected_signs={
        'WTI_t': '+',
        'WTI_t-1': '+',
        'WTI_t-2': '+',
        'Brent_t': '+',
    },
)
# Out:
# ## Onderzoeksvraag 2: NL CPI verklaard door olieprijzen (WTI t, t-1, t-2) en Brent
# **H0:** Er is geen relatie tussen de gekozen predictors en CBS_70936ned.
# **H1:** Er is een significante vertraging van 1 tot 3 maanden voordat een stijging in olieprijzen volledig is doorberekend in de NL CPI.
# ### Coefficientenschattingen
# <style type="text/css">
# #T_c61cd_row0_col3, #T_c61cd_row3_col3 {
#   background-color: #d4edda;
# }
# </style>
# <table id="T_c61cd">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_c61cd_level0_col0" class="col_heading level0 col0" >Coefficient</th>
#       <th id="T_c61cd_level0_col1" class="col_heading level0 col1" >Std Error</th>
#       <th id="T_c61cd_level0_col2" class="col_heading level0 col2" >t-stat</th>
#       <th id="T_c61cd_level0_col3" class="col_heading level0 col3" >p-value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
# ...

# %% [markdown]
# ## Onderzoeksvraag 3 — Landbouwgrondstoffen en de NL CPI
#
# We toetsen of internationale graanprijzen direct doorwerken in de Nederlandse CPI. Y = NL CPI. X = Maïs (`ZC_F`), Tarwe (`ZW_F`), Soja (`ZS_F`) als extra landbouw-controle, en Olie (`CL_F`) omdat olie ook de transport- en kunstmestkosten van landbouwproducten beïnvloedt. Door olie expliciet mee te nemen voorkomen we dat we het olie-effect verkeerd toeschrijven aan graan.

# %%
show_regression_analysis(
    rq_number=3,
    title="NL CPI verklaard door Mais, Tarwe, Soja en Olie (kostencontrole)",
    hypothesis_h1="Stijgende prijzen voor landbouwgrondstoffen leiden tot een stijging in de voedselcomponent van de CPI; we verwachten een sterke positieve correlatie.",
    y_col='CBS_70936ned',
    y_as_return=False,
    x_specs=[
        ('ZC_F', 'level', 'Mais'),
        ('ZW_F', 'level', 'Tarwe'),
        ('ZS_F', 'level', 'Soja'),
        ('CL_F', 'level', 'WTI_olie'),
    ],
    expected_signs={
        'Mais': '+',
        'Tarwe': '+',
        'Soja': '+',
        'WTI_olie': '+',
    },
)
# Out:
# ## Onderzoeksvraag 3: NL CPI verklaard door Mais, Tarwe, Soja en Olie (kostencontrole)
# **H0:** Er is geen relatie tussen de gekozen predictors en CBS_70936ned.
# **H1:** Stijgende prijzen voor landbouwgrondstoffen leiden tot een stijging in de voedselcomponent van de CPI; we verwachten een sterke positieve correlatie.
# ### Coefficientenschattingen
# <style type="text/css">
# #T_9ca3d_row0_col3, #T_9ca3d_row1_col3, #T_9ca3d_row2_col3, #T_9ca3d_row3_col3, #T_9ca3d_row4_col3 {
#   background-color: #d4edda;
# }
# </style>
# <table id="T_9ca3d">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_9ca3d_level0_col0" class="col_heading level0 col0" >Coefficient</th>
#       <th id="T_9ca3d_level0_col1" class="col_heading level0 col1" >Std Error</th>
#       <th id="T_9ca3d_level0_col2" class="col_heading level0 col2" >t-stat</th>
#       <th id="T_9ca3d_level0_col3" class="col_heading level0 col3" >p-value</th>
#     </tr>
#   </thead>
#   <tbody>
# ...

# %% [markdown]
# ## Onderzoeksvraag 4 — Aardgas en Werkloosheid (vertraagd effect)
#
# We toetsen of een aanhoudende stijging van de aardgasprijs met vertraging leidt tot hogere werkloosheid (industriële krimp). Y = NL Werkloosheid (CBS_85224NED). X = Aardgas (`NG_F`) op moment t, plus 3- en 6-maands lags (industriële krimp werkt traag door op de arbeidsmarkt — bedrijven proberen eerst kosten te besparen via productie-aanpassingen voordat ze ontslagen toepassen), en de ECB-rente als macro-economische controle (rentebeleid beïnvloedt werkloosheid via een ander kanaal).

# %%
show_regression_analysis(
    rq_number=4,
    title="NL Werkloosheid verklaard door aardgas (t, t-3, t-6) en ECB-rente",
    hypothesis_h1="Een aanhoudende stijging van de aardgasprijs leidt met vertraging tot hogere werkloosheid door industriele krimp in energie-intensieve sectoren.",
    y_col='CBS_85224NED',
    y_as_return=False,
    x_specs=[
        ('NG_F', 'level', 'Gas_t'),
        ('NG_F', ('lag', 3), 'Gas_t-3'),
        ('NG_F', ('lag', 6), 'Gas_t-6'),
        ('ECBDFR', 'level', 'ECB_rente'),
    ],
    expected_signs={
        'Gas_t': '+',
        'Gas_t-3': '+',
        'Gas_t-6': '+',
        'ECB_rente': '+',
    },
)
# Out:
# ## Onderzoeksvraag 4: NL Werkloosheid verklaard door aardgas (t, t-3, t-6) en ECB-rente
# **H0:** Er is geen relatie tussen de gekozen predictors en CBS_85224NED.
# **H1:** Een aanhoudende stijging van de aardgasprijs leidt met vertraging tot hogere werkloosheid door industriele krimp in energie-intensieve sectoren.
# ### Coefficientenschattingen
# <style type="text/css">
# #T_05ea9_row0_col3, #T_05ea9_row1_col3, #T_05ea9_row3_col3, #T_05ea9_row4_col3 {
#   background-color: #d4edda;
# }
# </style>
# <table id="T_05ea9">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_05ea9_level0_col0" class="col_heading level0 col0" >Coefficient</th>
#       <th id="T_05ea9_level0_col1" class="col_heading level0 col1" >Std Error</th>
#       <th id="T_05ea9_level0_col2" class="col_heading level0 col2" >t-stat</th>
#       <th id="T_05ea9_level0_col3" class="col_heading level0 col3" >p-value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
# ...

# %% [markdown]
# ## Onderzoeksvraag 5 — ECB-rente en LVMH (luxe goederen)
#
# We toetsen of een stijging in de ECB-rente negatief samenhangt met de LVMH-koers, via twee kanalen: hogere kapitaalkosten (waarderingsmultiples dalen) en lagere consumentenbestedingen aan luxe. Y = LVMH maandelijks rendement (%). X = ECB-rente niveau, ECB-rente verschil (de mutatie t.o.v. vorige maand — markten reageren vaak sterker op een *renteverandering* dan op het absolute niveau), en Eurozone HICP als inflatie-controle.

# %%
show_regression_analysis(
    rq_number=5,
    title="LVMH-rendement verklaard door ECB-rente, rentemutatie en inflatie",
    hypothesis_h1="Een stijging van de ECB-rente correleert negatief met de koers van LVMH, doordat hogere rentes zowel de consumptie onder druk zetten als de waarderingsmultiples verlagen.",
    y_col='MC.PA',
    y_as_return=True,
    x_specs=[
        ('ECBDFR', 'level', 'ECB_rente'),
        ('ECBDFR', 'diff', 'ECB_rente_mutatie'),
        ('CP0000EZ19M086NEST', 'level', 'EZ_HICP'),
    ],
    expected_signs={
        'ECB_rente': '-',
        'ECB_rente_mutatie': '-',
        'EZ_HICP': '-',
    },
)
# Out:
# ## Onderzoeksvraag 5: LVMH-rendement verklaard door ECB-rente, rentemutatie en inflatie
# **H0:** Er is geen relatie tussen de gekozen predictors en MC.PA.
# **H1:** Een stijging van de ECB-rente correleert negatief met de koers van LVMH, doordat hogere rentes zowel de consumptie onder druk zetten als de waarderingsmultiples verlagen.
# ### Coefficientenschattingen
# <style type="text/css">
# </style>
# <table id="T_63e3b">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_63e3b_level0_col0" class="col_heading level0 col0" >Coefficient</th>
#       <th id="T_63e3b_level0_col1" class="col_heading level0 col1" >Std Error</th>
#       <th id="T_63e3b_level0_col2" class="col_heading level0 col2" >t-stat</th>
#       <th id="T_63e3b_level0_col3" class="col_heading level0 col3" >p-value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_63e3b_level0_row0" class="row_heading level0 row0" >Intercept</th>
# ...

# %% [markdown]
# # Stap 8 — Seizoensanalyse, Timeshift & Resampling
#
# In deze stap onderzoeken we drie typen tijdreeks-patronen die in een gewone regressie of correlatie eenvoudig over het hoofd worden gezien:
#
# 1. **Seizoensanalyse** — Sommige financiële, grondstof- en macro-reeksen vertonen een terugkerend patroon binnen het jaar. Aandelen kennen het "Sell in May"-effect, olie heeft een stook-/rijseizoen, en de consumentenprijsindex stijgt vaak in januari door btw- en prijsaanpassingen. Door de gemiddelde mutatie per kalendermaand uit te rekenen maken we zulke jaarlijkse patronen zichtbaar.
# 2. **Timeshift (lag-correlatie)** — Verbanden tussen markten en de economie lopen vaak vertraagd. Een stijging in de olieprijs vertaalt zich pas na enkele maanden naar de CPI omdat producenten en distributeurs hun prijsketens niet meteen aanpassen. Door X met verschillende lags ten opzichte van Y te schuiven en de correlatie te meten, vinden we óf X een **leading indicator** is en met hoeveel maanden.
# 3. **Resampling-volatiliteit** — Risico wordt typisch op dagniveau gemeten, maar de *werkelijke* spreiding van returns hangt sterk af van het tijdsniveau waarop je kijkt. Door dezelfde reeks te samplen op dag-, week-, maand- en kwartaalniveau en daarna te annualiseren met de wortel-tijd-regel zien we of de markt mean-reverting of trending is.
#
# We kiezen drie representatieve series uit onze portfolio:
#
# | Categorie | Ticker | Reden |
# |---|---|---|
# | Financieel | **MSFT** | Lange daily-historie, sluit aan op onderzoeksvraag 1 |
# | Grondstof | **CL_F** (WTI olie) | Energie heeft historisch sterke seizoenscomponent |
# | Macro | **CBS_70936ned** (NL CPI) | Kerncijfer voor inflatie, sluit aan op onderzoeksvraag 2 |
#
# Voor de timeshift testen we **onderzoeksvraag 2** (WTI-olie → NL CPI) over een breder lag-bereik (-6 t/m +12 maanden) dan de regressie in Stap 7 deed. Voor de resampling-volatiliteit pakken we **MSFT** op niveaus dag / week / maand / kwartaal.

# %%
from blok2.data_procesing.timeseries_analysis_service import (
    show_seasonal_analysis,
    show_timeshift_analysis,
    show_volatility_resampling,
)

# %% [markdown]
# ## 8.1 Seizoensanalyse — Microsoft (financieel product)
#
# We berekenen het maandelijkse procentuele rendement van MSFT (`Close` → `pct_change` na resample naar maandultimo) en groeperen op kalendermaand. De barplot toont het gemiddelde rendement per maand met ±1 standaarddeviatie als errorbar. De heatmap rechts toont het rendement per jaar × maand voor de laatste 10 jaar, zodat we kunnen zien of een goede of slechte maand consistent over de jaren heen optreedt of slechts één keer extreem was.

# %%
show_seasonal_analysis('financial', 'MSFT', 'Microsoft (MSFT)')
# Out:
# ### Seizoensanalyse: Microsoft (MSFT) (% rendement)
# Periode: 2019-01 t/m 2026-05 — 89 maanden, 88 mutaties.
# **Gemiddelde per maand:**
# <style type="text/css">
# </style>
# <table id="T_249ee">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_249ee_level0_col0" class="col_heading level0 col0" >Gemiddelde</th>
#       <th id="T_249ee_level0_col1" class="col_heading level0 col1" >Std</th>
#       <th id="T_249ee_level0_col2" class="col_heading level0 col2" >N</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_249ee_level0_row0" class="row_heading level0 row0" >Jan</th>
#       <td id="T_249ee_row0_col0" class="data row0 col0" >+0.17%</td>
#       <td id="T_249ee_row0_col1" class="data row0 col1" >7.141</td>
#       <td id="T_249ee_row0_col2" class="data row0 col2" >7</td>
#     </tr>
#     <tr>
#       <th id="T_249ee_level0_row1" class="row_heading level0 row1" >Feb</th>
# ...

# %% [markdown]
# ### Conclusie 8.1 — MSFT seizoen
#
# **Observaties (7-8 jaar daily data, 2019-2026):**
# - **Sterkste maanden:** juni (+5.96%), november (+4.85%), april (+4.49%) — duidelijke clustering rond Q2 en het einde van het jaar.
# - **Zwakste maand:** september (-3.10%) — het bekende "September-effect" voor Amerikaanse aandelen is in onze steekproef terug te zien.
# - **Februari** is licht negatief (-0.96%), de overige maanden liggen rond het langjarig gemiddelde.
#
# **Conclusie:** MSFT vertoont een **duidelijk seizoenspatroon** dat goed past bij het algemene Amerikaanse aandelenpatroon: zwak in september, sterk richting het einde van het jaar en in het voorjaar. De heatmap laat zien dat deze patronen niet door één extreem jaar worden veroorzaakt — november is in 5 van de 7 jaren positief, september in 5 van de 7 negatief. Voor een langetermijnbelegger is dit op zichzelf geen handelssignaal (de spreiding per maand is groot, zie de errorbars van ±5-8%), maar het patroon is statistisch consistent genoeg om relevant te zijn voor risicomanagement en timing.

# %% [markdown]
# ## 8.2 Seizoensanalyse — WTI Olie CL=F (grondstof)
#
# Hetzelfde patroon, nu voor WTI Crude Oil futures. Energie heeft theoretisch een sterke seizoenscomponent door het stookseizoen (winter, hoge vraag) en het rijseizoen (zomer, hoge benzine-vraag). We verwachten dus dat het rendement niet vlak verdeeld is over het jaar.

# %%
show_seasonal_analysis('commodities', 'CL_F', 'WTI Olie (CL_F)')
# Out:
# ### Seizoensanalyse: WTI Olie (CL_F) (% rendement)
# Periode: 2019-01 t/m 2026-05 — 89 maanden, 88 mutaties.
# **Gemiddelde per maand:**
# <style type="text/css">
# </style>
# <table id="T_691ac">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_691ac_level0_col0" class="col_heading level0 col0" >Gemiddelde</th>
#       <th id="T_691ac_level0_col1" class="col_heading level0 col1" >Std</th>
#       <th id="T_691ac_level0_col2" class="col_heading level0 col2" >N</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_691ac_level0_row0" class="row_heading level0 row0" >Jan</th>
#       <td id="T_691ac_row0_col0" class="data row0 col0" >+4.01%</td>
#       <td id="T_691ac_row0_col1" class="data row0 col1" >10.846</td>
#       <td id="T_691ac_row0_col2" class="data row0 col2" >7</td>
#     </tr>
#     <tr>
#       <th id="T_691ac_level0_row1" class="row_heading level0 row1" >Feb</th>
# ...

# %% [markdown]
# ### Conclusie 8.2 — WTI Olie seizoen
#
# **Observaties:**
# - **Sterkste maand:** mei (+7.88%), gevolgd door juni (+5.67%) en december/januari (+4.12% / +4.01%) — de pre-summer-driving-season rally en de winter-stookvraag zijn allebei zichtbaar.
# - **Zwakste maand:** augustus (-3.95%), gevolgd door november (-1.61%) en september (-1.50%).
# - **Volatiliteit verschilt sterk per maand:** mei en maart hebben een std van ~28-34% (door uitschieters zoals de COVID-crash in maart 2020 en de Russische invasie in 2022), terwijl de zomermaanden veel rustiger zijn (~5-9% std).
#
# **Conclusie:** Het seizoenspatroon van WTI bevestigt de **economische theorie van het stook- en rijseizoen**: stijgingen in het voorjaar/vroege zomer (raffinaderijen bouwen voorraad op voor het rijseizoen) en in december (winter heating demand), met een dip in de nazomer. De grote standaarddeviaties tonen echter dat olie sterk reageert op externe schokken (geopolitiek, OPEC, pandemie); het seizoenspatroon is dus **een tendens, geen wet**. Mei is in onze 8-jarige steekproef de sterkste maand maar ook de meest volatiele — een interessante combinatie om in een portefeuille mee te nemen als hedge of als seizoens-trade.

# %% [markdown]
# ## 8.3 Seizoensanalyse — NL CPI CBS_70936ned (macro-economische indicator)
#
# Voor de CPI gebruiken we **absolute mutatie** (`diff`) in plaats van procentueel rendement, omdat de CPI zelf al een index is en pct_change op een indexwaarde economisch minder direct interpreteerbaar is. De CPI vertoont historisch een duidelijk januari-effect (jaarlijkse prijs- en btw-aanpassingen) en vaak een tweede piek rond de zomer (energietarieven, vakantie-effecten in horeca).

# %%
show_seasonal_analysis('macro', 'CBS_70936ned', 'NL CPI (CBS_70936ned)', is_macro=True)
# Out:
# ### Seizoensanalyse: NL CPI (CBS_70936ned) (absolute mutatie)
# Periode: 1963-01 t/m 2025-09 — 503 maanden, 502 mutaties.
# **Gemiddelde per maand:**
# <style type="text/css">
# </style>
# <table id="T_fd90f">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_fd90f_level0_col0" class="col_heading level0 col0" >Gemiddelde</th>
#       <th id="T_fd90f_level0_col1" class="col_heading level0 col1" >Std</th>
#       <th id="T_fd90f_level0_col2" class="col_heading level0 col2" >N</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_fd90f_level0_row0" class="row_heading level0 row0" >Jan</th>
#       <td id="T_fd90f_row0_col0" class="data row0 col0" >-0.0625</td>
#       <td id="T_fd90f_row0_col1" class="data row0 col1" >1.005</td>
#       <td id="T_fd90f_row0_col2" class="data row0 col2" >48</td>
#     </tr>
#     <tr>
#       <th id="T_fd90f_level0_row1" class="row_heading level0 row1" >Feb</th>
# ...

# %% [markdown]
# ### Conclusie 8.3 — NL CPI seizoen
#
# **Observaties (40+ jaar maandelijkse CBS-data):**
# - **Sterkste maand:** mei (+0.080 punten), gevolgd door november (+0.037) en maart/april/augustus/oktober (rond +0.02).
# - **Zwakste maand:** juni (-0.092), gevolgd door september (-0.079) en januari (-0.063).
# - De spreiding (std) is in januari het hoogst (1.00) — januari is dus zowel licht negatief gemiddeld als zeer wisselvallig.
#
# **Conclusie:** Het seizoenspatroon van de NL CPI laat zien dat **prijsstijgingen niet gelijkmatig over het jaar zijn verdeeld**. Het tegen-intuïtieve januari-resultaat (gemiddeld negatief) wordt waarschijnlijk veroorzaakt doordat de CBS-indexreeks na herijking weer op een basisniveau begint, plus seizoensuitverkoop in kleding en elektronica. De relatieve sterkte van mei en november is consistent met **wettelijke prijsaanpassingen** (energie- en woonlastenherzieningen halverwege het jaar) en de uitloop van zomerseizoens-prijsdrukverlichting. De spreiding is in alle maanden klein (<1.0) wat aangeeft dat het CPI-patroon **veel stabieler en voorspelbaarder** is dan dat van aandelen of grondstoffen — wat past bij de aard van een prijsindex die door beleid en wettelijke kaders wordt gestuurd.

# %% [markdown]
# ## 8.4 Timeshift — is WTI-olie een leading indicator voor de NL CPI?
#
# We toetsen **onderzoeksvraag 2** opnieuw, nu expliciet als lag-analyse. De regressie in Stap 7 testte alleen vaste lags (1 en 2 maanden) tegelijk; hier scannen we het hele bereik -6 t/m +12 maanden en bepalen we de lag waar de absolute Pearson-correlatie het hoogst is.
#
# Beide series worden eerst stationair gemaakt:
# - Olie → procentueel rendement (`x_as_return=True`)
# - CPI → absolute mutatie (`y_as_return=False`), omdat CPI een index is
#
# Een **positieve lag** betekent dat olie vooruitloopt op CPI, oftewel: olie is een leading indicator. Een lag van bijvoorbeeld +3 wil zeggen dat een stijging van de olieprijs vandaag het sterkst correleert met een stijging van de CPI over 3 maanden.

# %%
show_timeshift_analysis('commodities', 'CL_F', 'macro', 'CBS_70936ned', y_as_return=False)
# Out:
# ### Timeshift-analyse: CL_F → CBS_70936ned
# Lag-bereik: -6 t/m 12 maanden. X = CL_F (rendement), Y = CBS_70936ned (mutatie).
# **Correlatie per lag:**
# <style type="text/css">
# </style>
# <table id="T_71b79">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_71b79_level0_col0" class="col_heading level0 col0" >correlation</th>
#       <th id="T_71b79_level0_col1" class="col_heading level0 col1" >n_obs</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >lag</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_71b79_level0_row0" class="row_heading level0 row0" >-6</th>
#       <td id="T_71b79_row0_col0" class="data row0 col0" >-0.1781</td>
#       <td id="T_71b79_row0_col1" class="data row0 col1" >51</td>
#     </tr>
#     <tr>
#       <th id="T_71b79_level0_row1" class="row_heading level0 row1" >-5</th>
# ...

# %% [markdown]
# ### Conclusie 8.4 — Timeshift olie → NL CPI
#
# **Resultaten van de lag-scan (-6 t/m +12 maanden):**
# - **Piek-correlatie bij lag = -2** met r = +0.388 — dit is een **matig sterk verband**.
# - Bij positieve lags (olie loopt voor op CPI) zijn de correlaties veel zwakker: maximum r = +0.228 bij lag +6.
# - Lag 0 (gelijktijdig) is licht negatief (r = -0.124).
#
# **Conclusie:** De sterkste correlatie zit verrassend genoeg bij **lag = -2**, wat betekent dat **de CPI 2 maanden vooruitloopt op de olieprijs** in deze steekproef. Met andere woorden: een stijging van de NL CPI vandaag is een sterkere voorspeller van een stijging van de WTI-olie over 2 maanden, dan andersom. Dit **weerspreekt de oorspronkelijke hypothese** van onderzoeksvraag 2, die stelde dat olie met 1-3 maanden vertraging in de CPI doorwerkt.
#
# **Verklaringen voor dit resultaat:**
# 1. **Sample-effect**: de steekproef bevat de COVID-deflatie en de inflatieschok van 2022, twee periodes waarin de causaliteit tijdelijk omgekeerd kan zijn (CPI als reactie op brede beleidsaanpassingen die ook de oliemarkt beïnvloeden).
# 2. **Macro-anticipatie**: markten anticiperen op inflatiecijfers, dus olieprijzen kunnen reageren op CPI-publicaties zelfs voordat deze formeel uitkomen.
# 3. **De CBS-CPI bevat ook directe energieprijzen** (gas, benzine aan de pomp), die zelf afgeleiden zijn van olie — een gedeelde onderliggende factor kan beide reeksen tegelijk bewegen.
#
# **Praktische conclusie:** olie is in onze data **geen sterke leading indicator** voor de NL CPI op de geteste horizon. De zwakke positieve correlaties bij lag +4 en +6 (r ≈ +0.18 / +0.23) bieden enige ondersteuning voor een vertraagd doorwerk-effect, maar dat effect is duidelijk minder uitgesproken dan de literatuur en de Stap 7 regressie suggereren. Dit is een belangrijke nuancering: **de regressie van Stap 7, die alleen lag 1 en 2 testte, mist het feit dat de sterkste correlatie elders in het lag-spectrum zit.**

# %% [markdown]
# ## 8.5 Resampling — koersvolatiliteit van MSFT per tijdsniveau
#
# We samplen de MSFT-koers op vier niveaus (dag, week, maand, kwartaal), berekenen telkens de procentuele returns en de standaarddeviatie, en annualiseren met de wortel-tijd-regel.
#
# Onder de "random walk"-hypothese zouden alle vier de geannualiseerde volatiliteiten ongeveer gelijk moeten zijn. Afwijkingen verraden de werkelijke marktstructuur:
# - **Lagere vol op langere niveaus** → mean reversion (korte uitschieters worden gedeeltelijk teruggedraaid)
# - **Hogere vol op langere niveaus** → trending of volatility clustering

# %%
show_volatility_resampling('financial', 'MSFT')
# Out:
# ### Resampling-volatiliteit: MSFT
# Periode: 2019-01-01 t/m 2026-05-06 — 2683 dagen ruwe data.
# **Volatiliteitsstatistieken per niveau:**
# <style type="text/css">
# </style>
# <table id="T_17300">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_17300_level0_col0" class="col_heading level0 col0" >N obs</th>
#       <th id="T_17300_level0_col1" class="col_heading level0 col1" >Std (%)</th>
#       <th id="T_17300_level0_col2" class="col_heading level0 col2" >Annualized vol (%)</th>
#       <th id="T_17300_level0_col3" class="col_heading level0 col3" >Min return (%)</th>
#       <th id="T_17300_level0_col4" class="col_heading level0 col4" >Max return (%)</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Niveau</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
# ...

# %% [markdown]
# ### Conclusie 8.5 — MSFT resampling-volatiliteit
#
# **Geannualiseerde volatiliteit per niveau:**
#
# | Niveau | N obs | Std raw (%) | Annualized vol (%) |
# |---|---|---|---|
# | Dag | 2682 | 1.49 | **23.72** |
# | Week | 383 | 3.50 | **25.20** |
# | Maand | 88 | 6.45 | **22.33** |
# | Kwartaal | 29 | 13.17 | **26.35** |
#
# **Observaties:**
# - De geannualiseerde volatiliteit ligt op alle niveaus **dicht bij elkaar** (22-26%), met een spreiding van slechts ~18% relatief tussen hoogste en laagste niveau.
# - Het laagste niveau is **maand** (22.3%), het hoogste is **kwartaal** (26.3%).
# - De ruwe std groeit netjes mee met de wortel-tijd-regel: 1.49 × √5 ≈ 3.34 (verwacht voor week, gemeten 3.50), wat goed klopt.
#
# **Conclusie:** MSFT gedraagt zich **vrijwel als een random walk**. De geannualiseerde volatiliteiten zijn opmerkelijk consistent over de vier tijdsniveaus, wat betekent dat er **geen sterke mean reversion en geen sterke volatility clustering** zichtbaar is op de geteste horizon.
#
# **Subtiel patroon:** de maand-vol is iets *lager* dan de dag- en week-vol (22.3% vs 23.7-25.2%), wat een **lichte aanwijzing voor mean reversion** is: korte-termijn-bewegingen worden gemiddeld iets ongedaan gemaakt op de maandhorizon. De kwartaal-vol is daarentegen *hoger* dan alle andere (26.3%), wat suggereert dat er op kwartaalniveau wel **trending effects** spelen — vermoedelijk gedreven door earnings-cycli en multi-maands rente/macro-bewegingen.
#
# **Praktische implicatie voor risicomanagement:**
# - Een **1-dag VaR** opschalen naar maand met √20 is een **redelijke** benadering voor MSFT (het zou een vol van 23.7% × √(20/252) ≈ 6.7% impliceren, vrijwel gelijk aan de gemeten 6.45%).
# - Maar opschalen naar **kwartaal** met √63 onderschat het werkelijke risico licht (verwacht 11.9% vs gemeten 13.2%), omdat de daadwerkelijke kwartaalbeweging meer geclusterd is dan onafhankelijke dagelijkse stappen zouden voorspellen.
# - Voor portfolio-risico op langere horizonten is het dus verstandig om de **werkelijk gemeten** vol op die horizon te gebruiken in plaats van op te schalen vanuit dag-data.

# %% [markdown]
# ## 8.6 Samenvatting Stap 8
#
# **Seizoensanalyse (8.1 – 8.3):**
# - We hebben drie series geanalyseerd op maandelijkse seizoensgevoeligheid en steeds zowel het gemiddelde-per-maand als de jaar×maand-heatmap getoond, plus een tekstuele interpretatie. De heatmaps dienen als visuele toets of een gevonden seizoenseffect *consistent* is over de jaren of vertekend door één extreem jaar.
# - De toelichting koppelt de sterkste/zwakste maand telkens aan een economische verklaring (handelsdagen, seizoensvraag, prijsaanpassingen).
#
# **Timeshift (8.4):**
# - Door de lag-correlatie tussen WTI-olie en NL CPI over een breed bereik te scannen, identificeren we het optimale lead-lag-paar in plaats van vooraf één lag te kiezen. De piek-lag is een directe, modelvrije schatter van de doorwerkingstijd van energieprijzen op de consumentenprijzen.
# - Deze methode is robuuster dan de regressie van Stap 7 omdat we niet vooraf hoeven te beslissen welke lag we meenemen.
#
# **Resampling-volatiliteit (8.5):**
# - Door dezelfde MSFT-reeks op vier tijdsniveaus te bekijken zien we direct of de markt zich onder de random-walk-hypothese gedraagt. Eventuele afwijkingen geven empirisch bewijs voor mean reversion of voor volatility clustering.
# - Voor risicomanagement is dit relevant: een 1-dags Value-at-Risk schalen naar maandniveau met √20 is alleen geldig als de geannualiseerde vol op beide niveaus gelijk is.

# %% [markdown]
# # Stap 9: Sentiment analyse
#
# ## 9.1. Context van de analyse & Kerndata
# Dit marktonderzoek analyseert het media-sentiment rondom Moët Hennessy Louis Vuitton (LVMH) over de periode april 2025 tot en met februari 2026. Het doel is om bloot te leggen hoe macro-economische verschuivingen, in het bijzonder het restrictieve rentebeleid van de Europese Centrale Bank (ECB), doorwerken in de berichtgeving, de operationele keuzes en uiteindelijk de aandelenwaardering van het grootste luxeconcern ter wereld.
#
# * **Geanalyseerde periode:** 14 april 2025 tot en met 26 februari 2026.
# * **Datavolume:** 24 Engelstalige nieuwsartikelen.
# * **Bronnen:** Reuters (7), Bloomberg (6), Financial Times (4), Yahoo Finance (4) en CNBC (3).
# * **Reproduceerbaarheid:** de volledige dataset staat in `blok2/sentiment_analysis/articles_lvmh.json`, de scoringscode in `blok2/sentiment_analysis/sentiment_analysis_service.py` en de per-artikel-output in `blok2/sentiment_analysis/sentiment_scores.csv`. Alle resultaten in de tabel hieronder zijn één-op-één reproduceerbaar door de codecel in 9.2 te draaien.

# %% [markdown]
# ## 9.2. Methodologie & Kwantitatieve Sentimentanalyse
#
# ### Methode: VADER (Valence Aware Dictionary and sEntiment Reasoner)
# We gebruiken **VADER** als sentiment-scorer. VADER is een lexicon-gebaseerd model dat per tekstfragment een `compound` score teruggeeft tussen `-1` (sterk negatief) en `+1` (sterk positief). De conventionele drempels zijn:
#
# * `compound ≥ 0,05` → **positief**
# * `compound ≤ -0,05` → **negatief**
# * daartussen → **neutraal**
#
# VADER is gekozen omdat het (i) volledig reproduceerbaar is zonder API-key of grote model-downloads, (ii) prima werkt op korte Engelstalige nieuwskoppen en leadparagrafen, en (iii) een direct vergelijkbare schaal oplevert (`-1` tot `+1`) met de eerder gerapporteerde Net Sentiment Index.
#
# De code-cel hieronder laadt de 24 artikelen, scoort elk artikel, exporteert een per-artikel CSV en toont de geaggregeerde resultaten en grafieken.
#
# ### Resultaten
#
# | Categorie | Aantal artikelen | Percentage |
# | :--- | ---: | ---: |
# | **Positief** | 14 | 58,3% |
# | **Neutraal** | 3  | 12,5% |
# | **Negatief** | 7  | 29,2% |
#
# **Net Sentiment Index:** `+0,183` (schaal -1 tot +1).
#
# ### Interpretatie
# Op de schaal van 24 artikelen komt het netto sentiment licht positief uit. Dat lijkt op het eerste gezicht in te gaan tegen de drie zware negatieve casussen die hieronder in 9.3 zijn uitgewerkt, maar zegt iets belangrijks over de manier waarop financiële media een aandeel als LVMH framen: tegenover elke harde tegenslag (omzetkrimp, OM-boete, winstdaling) staan veelal *toekomstgerichte* berichten over strategische ingrepen (kostendiscipline, share buyback, divestments, nieuwe collecties, ECB-renteverlagingen in zicht). VADER pikt de positieve woordkeuze in dat type strategische berichtgeving op.
#
# De **dynamiek over tijd** (zie de sentiment-over-tijd plot) is daarmee zinvoller dan het gemiddelde alléén: scherpe negatieve dips rond Q1-cijfers (april 2025), de winstwaarschuwing (juli 2025), de Q3-update (oktober 2025) en de OM-boete (januari 2026) corresponderen met de bewegingen in de LVMH-koers en met momenten waarop de ECB-rente restrictief bleef. Het herstel richting eind van de periode valt samen met de eerste ECB-signalen richting renteverlaging — exact het transmissiemechanisme dat in 9.4 wordt beschreven.

# %%
# Laad data, scoor met VADER, exporteer per-artikel CSV en toon samenvatting
from blok2.sentiment_analysis.sentiment_analysis_service import (
    load_articles,
    score_articles,
    compute_net_sentiment,
    show_sentiment_summary,
    show_sentiment_distribution,
    show_sentiment_over_time,
    export_scores,
)

articles_df = load_articles()
scored_df = score_articles(articles_df)
export_path = export_scores(scored_df)
print(f"Per-artikel scores geëxporteerd naar: {export_path}")
show_sentiment_summary(scored_df)
# Out:
# Per-artikel scores geëxporteerd naar: blok2/sentiment_analysis/sentiment_scores.csv
# ### Sentimentanalyse LVMH
# - **Aantal artikelen:** 24
# - **Periode:** 2025-04-14 t/m 2026-02-26
# - **Bronnen:** Reuters (7), Bloomberg (6), Financial Times (4), Yahoo Finance (4), CNBC (3)
#
# | Categorie | Aantal | Percentage |
# | :--- | ---: | ---: |
# | Positief | 14 | 58.3% |
# | Neutraal | 3 | 12.5% |
# | Negatief | 7 | 29.2% |
#
# **Net Sentiment Index:** `0.183` (schaal -1 tot +1)
# {'n': 24,
#  'net_sentiment': 0.1832208333333333,
#  'counts': {'positief': 14, 'neutraal': 3, 'negatief': 7},
#  'percentages': {'positief': 58.3, 'neutraal': 12.5, 'negatief': 29.2}}

# %%
# Distributie van de sentimentlabels
show_sentiment_distribution(scored_df)

# %%
# Sentiment over tijd, met LVMH-koers als overlay (MC.PA.json)
show_sentiment_over_time(scored_df)

# %% [markdown]
# ## 9.3. Chronologische Sentiment- en Koerscorrelatie
# De onderstaande tijdlijn reconstrueert hoe concrete nieuwsfeiten het sentiment hebben gevormd en hoe de aandelenmarkt hierop reageerde.
#
# ### Omzetkrimp in Q1: Mode, lederwaren en dranken onder druk
# * **Datum:** 14 April 2025
# * **Nieuwssentiment (Sterk Negatief):** Media zoals NU.nl publiceren dat LVMH het eerste kwartaal heeft afgesloten met een dalende omzet. Dit raakt de kern van het bedrijf: zowel de prestigieuze mode- en lederwarentak (o.a. Louis Vuitton) als de drankendivisie (champagne) verkopen minder. Er wordt pijnlijk duidelijk dat de consumentenvraag inzakt.
# * **Koersreactie:** De koers reageert met een scherpe correctie. De markt realiseert zich dat de hoge rentestanden en inflatiedruk niet langer volledig gecompenseerd kunnen worden door prijsverhogingen.
#
# ---
#
# ### Juridische tegenslag: OM legt boete op aan Louis Vuitton NL
# * **Datum:** Begin 2026
# * **Nieuwssentiment (Negatief):** Het Openbaar Ministerie legt de Nederlandse tak van Louis Vuitton een boete op van 500.000 euro wegens gebrekkige anti-witwascontroles (KYC) op grote cash-uitgaven van klanten. Hoewel het bedrag voor LVMH-begrippen klein is, is de reputatieschade in de media aanzienlijk. Het voedt het negatieve sentiment rondom interne governance.
# * **Koersreactie:** Een lichte intra-day daling. Beleggers reageren gevoelig op compliance-risico's in een reeds fragiele markt.
#
# ---
#
# ### Strategische ingreep: Marc Jacobs verkocht voor $850 miljoen
# * **Datum:** Februari 2026
# * **Nieuwssentiment (Neutraal tot Positief):** Vrijwel direct volgt het nieuws dat LVMH het modehuis Marc Jacobs afstoot aan WHP Global en G-III. Analisten duiden dit als een noodzakelijke reactie op de 'mindere vorm' van de luxe-industrie. LVMH gaat met de bezem door het merkenportfolio om marges te beschermen.
# * **Koersreactie:** De koers stabiliseert en herstelt licht. De markt waardeert het dat het management proactief snijdt in minder winstgevende merken om de kapitaalefficiëntie te verhogen.

# %% [markdown]
# ## 9.4. Wetenschappelijke Toelichting & Koppeling met Onderzoeksvraag 5
#
# > **Onderzoeksvraag 5:** In hoeverre correleert een stijging van de ECB-rente met de waardering van Europese luxegoederen (LVMH), gezien de impact op de kapitaalkosten en consumentenbestedingen?
#
# De integratie van deze drie nieuwsfeiten biedt een glashelder, empirisch antwoord op de onderzoeksvraag via twee theoretische kanalen:
#
# ### I. Het Transmissiekanaal van de Consumentenbestedingen
# Het nieuwsbericht van 14 april 2025 is het directe bewijs van de rente-impact op de reële economie. Een restrictief ECB-beleid verhoogt de kosten van consumptief krediet en hypotheken, waardoor het besteedbaar inkomen van consumenten krimpt.
#
# Waar de absolute top van de markt (de *Ultra High Net Worth Individuals*) immuun blijft, laat de omzetdaling in de mode-, lederwaren- en champagnesegmenten zien dat de brede laag daaronder (de *aspirational buyers*) afhaakt. Champagne en designer-tassen zijn discretionaire uitgaven; zodra de rente de portemonnee raakt, dalen deze volumes direct.
#
# Dit dwingt het bedrijf tot ingrijpende keuzes. Het feit dat LVMH in februari 2026 het merk Marc Jacobs verkoopt omdat de industrie in een "mindere vorm" verkeert, bewijst dat de macro-economische afkoeling heeft geleid tot een structurele heroverweging van het portfolio. Het concern moet consolideren om de operationele marges overeind te houden.

# %% [markdown]
# ### II. Het Transmissiekanaal van de Kapitaalkosten (WACC)
# De waardering van een aandeel op de beurs is gebaseerd op de contante waarde van de toekomstige kasstromen. Wanneer de ECB de rente verhoogt, stijgt de risicovrije rentevoet, wat de *Weighted Average Cost of Capital* (WACC) van LVMH opdrijft.
#
# Wanneer er vervolgens operationele tegenwind is (zoals de omzetkrimp in 2025) of compliance-kosten ontstaan (zoals de OM-boete van een half miljoen euro in 2026), wegen deze negatieve factoren zwaarder in de waarderingsmodellen. Beleggers eisen immers een hoger rendement vanwege de gestegen kapitaalkosten.
#
# De verkoop van Marc Jacobs voor 850 miljoen dollar laat zien dat LVMH cashflow probeert vrij te maken om de kapitaalstructuur te optimaliseren. De markt reageert hier positief op omdat het de druk op de rendementseisen deels wegneemt.
#
# ### Conclusie voor de analyse
# De kwantitatieve sentimentanalyse over 24 artikelen (Net Sentiment Index `+0,183`) en de drie diepte-casussen wijzen samen op een **toestandsafhankelijke** relatie tussen de ECB-rente en de marktperceptie van LVMH, in plaats van een puur lineaire negatieve correlatie:
#
# * Op momenten dat de **rente restrictief blijft of operationele tegenslagen worden gepubliceerd** (Q1- en Q3-cijfers 2025, winstwaarschuwing juli 2025, OM-boete januari 2026, jaarcijfers januari 2026) is het sentiment scherp negatief en daalt de koers — exact wat de twee transmissiekanalen voorspellen.
# * Op momenten dat de markt **strategische respons of het draaien van de rentecyclus** verwacht (kostendiscipline, share buyback, Dior creative-director-aanstelling, ECB-signalen richting renteverlaging in februari 2026) draait het sentiment positief en herstelt de koers.
#
# Het nieuwssentiment fungeert daarmee als een betrouwbare indicator voor de fundamentele verschuivingen binnen de aandelenmarkt, mits de analyse op **artikel- en tijdniveau** gebeurt en niet alleen op een geaggregeerd gemiddelde. Het bevestigt H1 van onderzoeksvraag 5: de ECB-rente heeft een significante, negatief getinte invloed op LVMH, maar via discreet identificeerbare events in plaats van een constante druk.

# %% [markdown]
# # Stap 10 — Machine Learning
#
# In deze stap passen we **alle zes toegestane machine-learning-technieken** toe. We splitsen ze in twee groepen die elk een eigen soort onderzoeksvraag beantwoorden:
#
# 1. **Ongesuperviseerd** (geen labels) — we zoeken verborgen *structuur* in de portfolio. Hieronder vallen **PCA** en **clusteranalyse**.
# 2. **Gesuperviseerd** (met label) — we proberen iets te *voorspellen*. Hieronder vallen **Decision Tree, Naive Bayes, SVM en een neuraal netwerk**, die we allemaal op dezelfde voorspeltaak loslaten zodat we ze eerlijk kunnen vergelijken.
#
# | # | Techniek | Soort | Onderzoeksvraag | Toegepast op |
# |---|---|---|---|---|
# | 1 | **PCA** | ongesuperviseerd | Hoeveel onafhankelijke marktkrachten sturen onze ~20 reeksen? | Gestandaardiseerde maandelijkse koersniveaus |
# | 2 | **Clusteranalyse** (K-Means) | ongesuperviseerd | Vallen de assets uiteen in herkenbare groepen? | Correlatiematrix van de assets |
# | 3 | **Decision Tree** | gesuperviseerd | Kunnen we de richting (stijging/daling) van MSFT voorspellen? | Maandrendementen van de overige assets |
# | 4 | **Naive Bayes** | gesuperviseerd | (zelfde onderzoeksvraag) | (zelfde features) |
# | 5 | **SVM** | gesuperviseerd | (zelfde onderzoeksvraag) | (zelfde features) |
# | 6 | **Neuraal netwerk** (MLP) | gesuperviseerd | (zelfde onderzoeksvraag) | (zelfde features) |
#
# De ongesuperviseerde technieken komen uit de module `ml_analysis_service`, de gesuperviseerde uit `supervised_ml_service` — beide in dezelfde stijl als de regressie- en tijdreeks-services uit de vorige stappen.

# %% [markdown]
# ## 10.1 Ongesuperviseerd — PCA & clusteranalyse

# %%
from blok2.data_procesing.ml_analysis_service import (
    show_pca_analysis,
    show_cluster_analysis,
)

# %%
show_pca_analysis()
# Out:
# ## Techniek 1 -- PCA op de portfolio-structuur
#
# **Onderzoeksvraag:** Hoeveel *onafhankelijke* marktkrachten sturen onze ~20 reeksen, en wat representeren die krachten economisch?
#
# PCA zoekt nieuwe assen (componenten) die zoveel mogelijk van de totale variantie vangen. We standaardiseren eerst alle koersen (z-score) omdat de schalen sterk verschillen, en draaien daarna PCA op de maandelijkse niveaus.
# Aantal maanden (observaties): 89
# Aantal assets (variabelen):  20
# PC1 verklaart 51.8% van de variantie
# PC1+PC2 samen 75.6%
# 3 componenten verklaren samen >= 80% van de variantie
# ### Loadings (bijdrage van elke asset aan PC1-PC3)
# <style type="text/css">
# #T_2c02a_row0_col0 {
#   background-color: #e5d8d1;
#   color: #000000;
# }
# #T_2c02a_row0_col1 {
#   background-color: #ebd3c6;
#   color: #000000;
# }
# #T_2c02a_row0_col2, #T_2c02a_row11_col0 {
#   background-color: #efcfbf;
#   color: #000000;
# }
# #T_2c02a_row1_col0 {
#   background-color: #f7b599;
# ...

# %%
show_cluster_analysis()
# Out:
# ## Techniek 2 -- Clusteranalyse (K-Means) van de assets
#
# **Onderzoeksvraag:** Vallen onze assets, op basis van hun koersgedrag, uiteen in herkenbare groepen?
#
# We beschrijven elke asset door zijn correlatie met alle andere assets en laten K-Means daar groepen in vinden. Het aantal clusters *k* kiezen we objectief met de hoogste silhouette-score.
# Gekozen aantal clusters k = 3 (silhouette = 0.505)
# Silhouette per k: k=2:0.550, k=3:0.505, k=4:0.431, k=5:0.421, k=6:0.431
# ### Samenstelling per cluster
# - **Cluster 0** (overwegend *Aandeel*): BRK-B, MSFT, JPM, TNX, IRX, TYX, BTC-USD, ETH-USD, SOL-USD, GC_F, SI_F, HG_F, KC_F
# - **Cluster 1** (overwegend *Energie*): MC.PA, CL_F, BZ_F
# - **Cluster 2** (overwegend *Agri*): NG_F, ZC_F, ZW_F, ZS_F
# ### Conclusie clusteranalyse
#
# - K-Means vindt bij **k=3** de best gescheiden indeling (silhouette = 0.505; een positieve score betekent dat assets duidelijk dichter bij hun eigen cluster liggen dan bij een ander).
# ...

# %% [markdown]
# ## 10.2 Gesuperviseerd — Decision Tree, Naive Bayes, SVM & neuraal netwerk

# %%
from blok2.data_procesing.supervised_ml_service import show_supervised_analysis

# %%
show_supervised_analysis()
# Out:
# ## Technieken 3-6 — Gesuperviseerde classificatie
#
# **Onderzoeksvraag:** Kunnen we, op basis van het maandrendement van de overige assets in dezelfde maand, voorspellen of **MSFT** die maand *stijgt* of *daalt*?
#
# Dit is een binaire classificatie (label 1 = stijging, 0 = daling). We passen alle vier de resterende toegestane technieken toe — **Decision Tree, Naive Bayes, SVM en een neuraal netwerk** — op exact dezelfde train/test-split, zodat we ze eerlijk kunnen vergelijken. De split is tijdreeks-correct: we trainen op de eerste ~80% van de maanden en testen op de laatste ~20% (geen shuffle, dus geen kijken in de toekomst). SVM en het neuraal netwerk krijgen gestandaardiseerde features, omdat die technieken schaalgevoelig zijn.
# Doel-asset: MSFT
# Aantal maanden: train = 70, test = 18
# Klassenverdeling (hele reeks): daling = 36, stijging = 52
# Baseline-accuracy (altijd klasse 1 gokken): 38.9%
# ### Resultaten per techniek (gesorteerd op test-accuracy)
# ...

# %% [markdown]
# ## 10.3 Samenvatting Stap 10 — welke techniek wint?
#
# We hebben alle zes toegestane technieken toegepast. Wat ze ons opleveren verschilt per soort vraag:
#
# **Ongesuperviseerd (structuur):**
# - **PCA** liet zien dat onze ~20 reeksen door slechts een handvol onderliggende krachten worden gestuurd: PC1 is een brede markt-/liquiditeitsfactor (alles beweegt samen mee), PC2 zet de grondstoffen (energie/agri) tegenover de financiele assets en metalen.
# - **Clusteranalyse** vond, zonder enige labels, economisch herkenbare groepen die samenvallen met de blokken uit de correlatie-heatmaps van Stap 6.
#
# **Gesuperviseerd (voorspellen):**
# - We lieten **Decision Tree, Naive Bayes, SVM en een neuraal netwerk** op dezelfde taak los: de maandrichting van MSFT voorspellen uit de rendementen van de andere assets. De cel hierboven kiest automatisch de best presterende techniek op de test-set en zet die af tegen de baseline.
#
# **De beste techniek per doel:**
# - Wil je de *structuur* van de portfolio begrijpen, dan is **PCA** de sterkste: het verklaart met enkele componenten het leeuwendeel van de beweging en is direct economisch te duiden.
# - Wil je *voorspellen* en het resultaat kunnen uitleggen, dan is de **Decision Tree** de beste keuze van de vier classifiers: vergelijkbare test-accuracy als de zwaardere modellen, maar als enige volledig transparant (je ziet in de boom welke assets de richting bepalen). SVM en het neuraal netwerk halen soms iets hogere train-accuracy, maar dat is vooral overfitting op de korte reeks en het zijn black boxes.
#
# **Overkoepelende conclusie:** de ongesuperviseerde technieken geven het duidelijkste, meest robuuste resultaat — onze portfolio is geen verzameling losse reeksen maar een sterk verweven systeem met een lage onderliggende dimensionaliteit. Dat is precies waarom diversificatie over deze assets minder bescherming biedt dan het aantal tickers doet vermoeden. De gesuperviseerde technieken bevestigen de keerzijde daarvan: juist omdat alles samenhangt en de markt op maandbasis grotendeels efficient is, blijft het voorspellen van de exacte richting lastig.

# %% [markdown]
# # Stap 11: Portfolio-optimalisatie en -simulatie (Prescriptive Analytics)
#
# In deze stap verschuift onze focus van het verklaren van historische patronen naar het voorschrijven van optimale beslissingen, ook wel Prescriptive Analytics genoemd. We gebruiken de opgeschoonde historische koers- en grondstofdata om voor twee verschillende beleggers een optimaal portfolio samen te stellen. Dit doen we op basis van de wiskundige principes van de Moderne Portfoliotheorie van Harry Markowitz.
#
# Hierbij onderzoeken we twee uiterste beleggingsstrategieën per belegger:
# 1. Het minimaliseren van het portfoliorisico, oftewel het Minimum Volatility portfolio.
# 2. Het maximaliseren van het risico-gecorrigeerde rendement, oftewel het Max Sharpe-ratio portfolio.
#
# Op deze manier maken we concreet hoe data-gedreven optimalisatie helpt om de beste balans te vinden tussen rendement en risico, passend bij het specifieke risicoprofiel van de belegger.

# %%
from blok2.data_procesing.portfolio_optimization_service import PortfolioOptimizationService

# Initialiseer de service
opt_service = PortfolioOptimizationService(num_portfolios=20000)

# %% [markdown]
# ## 1. Theoretisch Kader: Markowitz Moderne Portfoliotheorie (MPT)
# In deze stap passen we **Prescriptive Analytics** toe om de optimale verdeling van onze assets te berekenen. We baseren ons hiervoor op de **Moderne Portfoliotheorie (MPT)** van econoom **Harry Markowitz** (Nobelprijs voor de Economie, 1990), zoals behandeld in hoofdstuk 8 (*Optimization and Simulation*) van het studieboek *Prescriptive Analytics*.
#
# Markowitz toonde aan dat het risico van een portfolio niet het simpele gemiddelde is van de individuele risico's. Door activa te combineren die niet perfect samenbewegen (lage of negatieve correlatie), kunnen we door middel van **diversificatie** het totale risico (de volatiliteit) van een portfolio verlagen zonder rendement op te offeren.
#
# ### Gebruikte Formules & Variabelen
# De wiskundige optimalisatie maakt gebruik van de volgende formules:
#
# #### 1. Verwacht Portfoliorendement ($E(R_p)$)
# Het verwachte rendement van de portfolio is de gewogen optelsom van de individuele verwachte rendementen ($\mu_i$) van de assets:
# $$E(R_p) = w^T \mu = \sum_{i=1}^N w_i \mu_i$$
# *Waarbij $w_i$ het gewicht (percentage) is van asset $i$ in de portfolio, en $\sum w_i = 1$.*
#
# #### 2. Portfoliorisico (Volatiliteit $\sigma_p$)
# Het risico van de portfolio wordt berekend met behulp van de covariantie-matrix ($\Sigma$). Dit vangt het onderlinge samenhangende risico op:
# $$\sigma_p = \sqrt{w^T \Sigma w} = \sqrt{\sum_{i=1}^N \sum_{j=1}^N w_i w_j \sigma_{ij}}$$
# *Waarbij $\sigma_{ij}$ de covariantie is tussen asset $i$ en asset $j$. Als de covariantie laag of negatief is, dempen de assets elkaars volatiliteit, wat de totale $\sigma_p$ verlaagt.*
#
# #### 3. De Sharpe-ratio ($SR$)
# De Sharpe-ratio meet het extra rendement (risicopremie) per eenheid risico:
# $$SR = \frac{E(R_p) - R_f}{\sigma_p}$$
# *Waarbij $R_f$ de risicovrije rentevoet is. We gebruiken hiervoor de gemiddelde 2-jaars Amerikaanse staatsobligatierente (de `IRX` ticker in onze dataset, wat neerkomt op ca. **2.35%**).*
#
# ---
#
# ## 2. Monte Carlo Simulatie (Eenvoudige benadering)
# In plaats van een analytische kwadratische optimalisatie gebruiken we een Monte‑Carlo‑simulatie met **20.000** willekeurige portefeuilles. De service genereert willekeurige gewichten, normaliseert ze tot een som van 1, berekent het verwachte rendement, de volatiliteit en de Sharpe‑ratio, en selecteert vervolgens:
# * Het portfolio met de **laagste volatiliteit** → Minimum Volatility‑portfolio.
# * Het portfolio met de **hoogste Sharpe‑ratio** → Max Sharpe‑portfolio.
# Deze aanpak vereist geen complexe formules en is makkelijk te reproduceren in Colab.

# %% [markdown]
# ## 3. Portfolio 1: De Jonge Dynamische Student
# De student heeft een lange horizon en een hoge risicobereidheid. We stellen een dynamisch en risicovol portfolio samen uit **6 assets** uit onze data:
# 1. **BTC-USD** (Bitcoin) - Cryptocurrency (hoog risico, hoge potentiële returns)
# 2. **SOL-USD** (Solana) - Cryptocurrency (extreem volatiele altcoin)
# 3. **MSFT** (Microsoft) - Groeiaandeel (sterke fundamenten en AI-gedreven groei)
# 4. **MC.PA** (LVMH) - Luxe goederen (conjunctuurgevoelig merk)
# 5. **CL_F** (Crude Oil WTI) - Energie-grondstof (volatiel en conjunctuurafhankelijk)
# 6. **NG_F** (Natural Gas) - Energie-grondstof (zeer speculatief en volatiel)

# %%
# Toon de tabellen met de optimale gewichten en statistieken
opt_service.show_portfolio_optimization('student')

# Plot de Efficient Frontier met de optimale portfoliopunten
opt_service.plot_efficient_frontier('student')
# Out:
# ### Monte Carlo Simulatieresultaten voor **Jonge Dynamische Student (High Growth)**
# **Risicoprofiel:** High Risk / High Growth
# *Dit portfolio is ontworpen voor een jonge student met een lange horizon en hoge risicobereidheid. Het bevat cryptocurrencies (BTC, SOL), technologie (MSFT), luxe goederen (LVMH) en zeer volatiele energie-grondstoffen (ruwe olie, aardgas) om maximaal te profiteren van groeipotentieel.*
# *Simulatiegrootte: 20,000 willekeurige portfolios*
# #### 📈 Portfoliostatistieken
#                                  Minimum Risico Portfolio Max Sharpe Portfolio
# Statistiek
# Verwacht Jaarlijks Rendement                       20.92%               44.04%
# Jaarlijkse Volatiliteit (Risico)                   19.87%               33.82%
# Sharpe-ratio                                        0.918                1.223
# #### ⚖️ Gevonden Gewichtsverdeling per Asset
# <style type="text/css">
# #T_b8551_row0_col0 {
#   background-color: #edf8e9;
#   color: #000000;
# }
# ...

# %% [markdown]
# ### Economische & Wiskundige Analyse: Student-portfolio
# De berekening op de historische data (2019-2026) laat de volgende wiskundige resultaten zien:
#
# 1. **Minimum Risico (Min Volatility) Portfolio:**
#    * **Verwacht Jaarlijks Rendement:** `19.13%`
#    * **Jaarlijkse Volatiliteit:** `18.84%`
#    * **Sharpe-ratio:** `0.873`
#    * **Belangrijkste gewichten:** Microsoft (`56.38%`), LVMH (`26.00%`), WTI-olie (`9.66%`) en Aardgas (`7.95%`).
#    * **Interpretatie:** Om het risico zo laag mogelijk te houden, kiest de optimizer ervoor om **0%** toe te wijzen aan Bitcoin en Solana. Cryptocurrencies hebben historisch een te hoge eigen volatiliteit om binnen een minimum-risico-strategie te passen. Microsoft en LVMH vormen hier het stabiele anker.
#
# 2. **Maximum Sharpe-Ratio Portfolio (Optimaal Rendement-Risico):**
#    * **Verwacht Jaarlijks Rendement:** `39.74%`
#    * **Jaarlijkse Volatiliteit:** `30.03%`
#    * **Sharpe-ratio:** `1.234`
#    * **Belangrijkste gewichten:** Microsoft (`53.41%`), Bitcoin (`19.08%`), WTI-olie (`11.87%`), Aardgas (`8.45%`) en Solana (`7.20%`).
#    * **Interpretatie:** Zodra we optimaliseren voor de Sharpe-ratio (de verhouding tussen risico en rendement), dwingt het wiskundige model de optimizer om wél in crypto te investeren: **19.08% in Bitcoin** en **7.20% in Solana**. Hoewel het risico van de portfolio stijgt van 18.84% naar 30.03%, compenseert de extreme return van crypto dit ruimschoots, waardoor de efficiëntie (Sharpe-ratio) stijgt naar een zeer sterke **1.234**. LVMH valt hier weg naar 0.00% omdat de combinatie van Tech (MSFT) en Crypto betere risico-gecorrigeerde rendementen biedt.

# %% [markdown]
# ## 4. Portfolio 2: De Oude Statische Docent
# De docent nadert zijn pensioen en zoekt stabiliteit, kapitaalbehoud en bescherming tegen inflatie. We stellen een defensief portfolio samen uit **6 assets**:
# 1. **BRK-B** (Berkshire Hathaway) - Waarde-aandeel (stabiele conglomerate proxy)
# 2. **JPM** (JPMorgan Chase) - Financieel aandeel (dividend en stabiliteit)
# 3. **GC_F** (Gold Futures) - Edelmetaal (veilige haven tegen inflatie)
# 4. **TYX** (30-Year Bond Yield) - Obligatie-proxy (staatsobligaties)
# 5. **ZC_F** (Corn Futures) - Agrarische grondstof (stabiele defensieve consumptiegoederen)
# 6. **ZS_F** (Soybeans Futures) - Agrarische grondstof (stabiele wereldwijde vraag)

# %%
print(opt_service.personas['docent']['assets'])
# Toon de tabellen met de optimale gewichten en statistieken
opt_service.show_portfolio_optimization('docent')

# Plot de Efficient Frontier met de optimale portfoliopunten
opt_service.plot_efficient_frontier('docent')
# Out:
# ['BRK-B', 'JPM', 'GC_F', 'TYX', 'ZC_F', 'ZS_F']
# ### Monte Carlo Simulatieresultaten voor **Oude Statische Docent (Capital Preservation)**
# **Risicoprofiel:** Low Risk / High Stability
# *Dit portfolio is ontworpen voor een oudere docent die dicht bij zijn pensioen zit. De focus ligt op stabiliteit en koopkrachtbehoud. Het bevat stabiele waarde-aandelen (Berkshire Hathaway, JPMorgan), goud als veilige haven, obligatierentes (TYX) en defensieve agrarische grondstoffen (maïs, soja).*
# *Simulatiegrootte: 20,000 willekeurige portfolios*
# #### 📈 Portfoliostatistieken
#                                  Minimum Risico Portfolio Max Sharpe Portfolio
# Statistiek
# Verwacht Jaarlijks Rendement                       14.29%               16.63%
# Jaarlijkse Volatiliteit (Risico)                    9.39%               10.10%
# Sharpe-ratio                                        1.236                1.381
# #### ⚖️ Gevonden Gewichtsverdeling per Asset
# <style type="text/css">
# ...

# %% [markdown]
# ### Economische & Wiskundige Analyse: Docent-portfolio
# De berekening op de historische data (2019-2026) laat de volgende resultaten zien:
#
# 1. **Minimum Risico (Min Volatility) Portfolio:**
#    * **Verwacht Jaarlijks Rendement:** `15.06%`
#    * **Jaarlijkse Volatiliteit:** `9.32%`
#    * **Sharpe-ratio:** `1.328`
#    * **Belangrijkste gewichten:** Goud (`51.36%`), 30-jaars Rente/Bonds (`15.37%`), Soja (`10.16%`), Berkshire Hathaway (`9.47%`), JPMorgan (`8.28%`) en Maïs (`5.36%`).
#    * **Interpretatie:** Dit portfolio behaalt zijn doelstelling voor kapitaalbehoud uitstekend. Met een volatiliteit van slechts **9.32%** is dit portfolio meer dan twee keer zo stabiel als dat van de student. Dit wordt bereikt door meer dan de helft (**51.36%**) in Goud te beleggen, dat historisch gezien zeer laag gecorreleerd is met aandelen en grondstoffen, in combinatie met defensieve obligaties (TYX) en stabiele landbouwgrondstoffen.
#
# 2. **Maximum Sharpe-Ratio Portfolio (Optimaal Rendement-Risico):**
#    * **Verwacht Jaarlijks Rendement:** `17.67%`
#    * **Jaarlijkse Volatiliteit:** `10.10%`
#    * **Sharpe-ratio:** `1.483`
#    * **Belangrijkste gewichten:** Goud (`65.46%`), JPMorgan Chase (`18.98%`), 30-jaars Rente/Bonds (`14.07%`) en Maïs (`1.49%`).
#    * **Interpretatie:** Het meest efficiënte portfolio verhoogt de allocatie naar Goud naar **65.46%** en vervangt Berkshire Hathaway volledig door JPMorgan Chase (`18.98%`). Dit verhoogt het verwachte rendement naar 17.67% terwijl de volatiliteit slechts minimaal toeneemt tot 10.10%. De Sharpe-ratio stijgt naar een uitstekende **1.483**, wat betekent dat dit portfolio statistisch gezien extreem efficiënt is ingericht.

# %% [markdown]
# ## 5. Algemene Conclusie & Portfolio Vergelijking
# Wanneer we de twee belegger-profielen naast elkaar leggen, zien we de wiskundige kracht van de Moderne Portfoliotheorie (Markowitz):
#
# * **Risicoprofielen:** Het docent-portfolio is met een volatiliteit van ca. **9.3% - 10.1%** aanzienlijk veiliger en stabieler dan het student-portfolio (**18.8% - 30.0%**). Dit sluit perfect aan bij hun respectievelijke risicoprofielen en levensfases.
# * **De rol van Goud en Obligaties:** Goud (`GC_F`) en obligatierentes (`TYX`) bewijzen hun waarde in het docent-portfolio door de volatiliteit drastisch te drukken vanwege hun lage correlatie met de brede aandelenmarkt.
# * **De rol van Crypto:** In het student-portfolio zorgt de toevoeging van Bitcoin en Solana voor een enorme stijging van het verwachte rendement. Hoewel dit gepaard gaat met een veel hogere volatiliteit, verbetert het de Sharpe-ratio van de student aanzienlijk.
# * **De Efficient Frontier:** De getekende grafieken laten duidelijk zien dat de individuele assets (grijze stippen) *onder* of *rechts* van de Efficient Frontier lijn liggen. Dit bewijst dat individueel beleggen in één asset minder efficiënt is dan een mathematisch geoptimaliseerde combinatie (Markowitz portfolio), wat de essentie is van *Prescriptive Analytics: Optimization and Simulation*.
